# %%
import torch

# %%
dropout = torch.nn.Dropout2d(p=0.2)
x = torch.randn(5, 3, 28, 28)
out = dropout(x)

# %%
idx = 4
print(x[idx])
print(f'{"-"*20}')
print(out[idx])
# Out:
# tensor([[[ 1.4914e+00, -2.2804e-01,  1.5010e+00,  ..., -6.6782e-01,
#            3.8689e-01,  1.5416e-01],
#          [-1.4219e+00, -9.0664e-01,  8.0588e-01,  ...,  6.1965e-02,
#            1.2035e-03, -8.5222e-03],
#          [-1.4677e+00, -5.8741e-01, -5.6883e-01,  ...,  4.0352e-01,
#            8.2665e-01,  8.3781e-01],
#          ...,
#          [-1.3549e+00,  3.6159e-01,  4.8970e-01,  ..., -3.4686e-01,
#           -1.6993e+00, -8.2874e-01],
#          [-2.1672e+00,  2.0313e+00,  9.5660e-01,  ...,  2.9134e-01,
#           -2.4354e-01,  2.1798e-02],
#          [-6.1711e-01,  1.3083e+00,  7.3605e-01,  ..., -8.5310e-01,
#            3.9007e-01, -1.5793e+00]],
#
#         [[-1.6799e+00, -1.3728e+00,  1.0423e+00,  ..., -2.0890e+00,
#            4.7470e-02, -2.0433e+00],
#          [ 1.7014e+00, -1.7918e+00, -1.9780e+00,  ..., -9.4444e-01,
#            1.3536e-01,  1.6854e+00],
#          [ 1.1735e+00, -2.2121e-01, -2.5299e+00,  ..., -6.0562e-01,
#            1.0787e+00, -1.4181e+00],
# ...
