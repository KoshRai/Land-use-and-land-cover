# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import os
import torchinfo
import torchvision
import torchvision.transforms as T
import math
import torchmetrics

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

xpath='/kaggle/input/sar8bit/Dataset/img_dir'
ypath='/kaggle/input/sar8bit/Dataset/ann_dir_8bit'
trn_hist_path='training_hist'
trn_out_path='/kaggle/working/train_imgs_out'
val_out_path='/kaggle/working/val_imgs_out'

# os.mkdir(trn_hist_path)
# os.mkdir(trn_out_path)
# os.mkdir(val_out_path)
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# cuda

# %%
def visualize_sample(img, label, title, path=''):
    fig, ax = plt.subplots(1, 6, figsize=(20,20))
    for i, subplot_ax in zip(range(5 + 1), ax.flatten()):
        if i == 0: 
            subplot_ax.imshow(img.permute(1,2,0))
            subplot_ax.set_title(title)
        else:
            subplot_ax.imshow(label[i-1], cmap='gray', vmin=0, vmax=1)
            subplot_ax.set_title(f'Label {i}')
    if path != '':
        plt.savefig(f'{path}/{title}.png')

def visualize_predictions(model, img, i, path):
    inp = img/255
    inp = torch.unsqueeze(inp, dim=0)
    pred = model(inp)
    visualize_sample(img, pred.squeeze().detach().numpy(), f'Model Predictions {i}', path)

accuracy = torchmetrics.Accuracy(task='multiclass', num_classes=5).to(device)

def acc(preds, label):
    return accuracy(preds, label)

# %%
class SARData(Dataset):
    def __init__(self):
        self.num_classes = 5
        self.height, self.width = 256,256
        #ADD ELASTIC TRANSFORMATIONS
        self.transforms = T.Compose([
            T.RandomHorizontalFlip(p=0.5),
            T.RandomVerticalFlip(p=0.5)
        ])
        self.xtrain_path = xpath #Path to inputs
        self.ytrain_path = ypath #Path to labels
        self.imgs = np.array(os.listdir(self.ytrain_path))
        
    def __len__(self):
        return len(self.imgs)
    
    def process_label(self, label):
        r = []
        for i in range(self.num_classes):
            mask = label == i+1
            mask = mask.float()
            r.append(mask)
        return torch.stack(r)
    
    def __getitem__(self, idx):        
        xtrain = cv.imread(f"{self.xtrain_path}/{self.imgs[idx]}")
        xtrain = cv.cvtColor(xtrain, cv.COLOR_BGR2RGB)
        xtrain = torch.tensor(xtrain).permute(2,0,1) #HWC -> CHW
        
        ytrain = cv.imread(f"{self.ytrain_path}/{self.imgs[idx]}", cv.IMREAD_GRAYSCALE)
        ytrain = torch.tensor(ytrain)
        ytrain = self.process_label(ytrain)
        
        xtrain = self.transforms(xtrain)
        ytrain = self.transforms(ytrain)
        return xtrain, ytrain

# %%
data = SARData()
train, val = torch.utils.data.random_split(data, [0.8, 0.2])

# %%
def double_conv(in_channels, out_channels):
    conv = nn.Sequential(
        nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(out_channels)
    )
    return conv

def double_Tconv(in_channels, out_channels):
    Tconv = nn.Sequential(
        nn.ConvTranspose2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.ConvTranspose2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(out_channels)
    )
    return Tconv

class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2, return_indices=True)
        self.max_unpool = nn.MaxUnpool2d(kernel_size=2, stride=2)
        self.conv1 = double_conv(3, 64)
        self.conv2 = double_conv(64, 128)
        self.conv3 = double_conv(128, 256)
        self.conv4 = double_conv(256, 512)
        self.conv5 = double_conv(512, 1024)
        self.Tconv5 = double_Tconv(1024, 512)
        self.Tconv4 = double_Tconv(1024, 256)
        self.Tconv3 = double_Tconv(512, 128)
        self.Tconv2 = double_Tconv(256, 64)
        self.Tconv1 = double_Tconv(128, 5)
        self.softmax = nn.Softmax(dim=1)
        self.dropout = nn.Dropout2d(p=0.2)
    
    def forward(self, x):
        c1 = self.conv1(x)
        x1, i1 = self.max_pool(c1)

        c2 = self.conv2(x1)
        x2, i2 = self.max_pool(c2)
        
        c3 = self.conv3(x2)
        x3, i3 = self.max_pool(c3)

        c4 = self.conv4(x3)
        x4, i4 = self.max_pool(c4)
        
        i = self.conv5(x4)
        
        i = self.dropout(i)
        
        t4 = self.Tconv5(i)
    
        z4 = torch.cat((self.max_unpool(t4, i4, output_size=c4.size()), c4), dim=1)
        t3 = self.Tconv4(z4)
        
        z3 = torch.cat((self.max_unpool(t3, i3, output_size=c3.size()), c3), dim=1)
        t2 = self.Tconv3(z3)
    
        z2 = torch.cat((self.max_unpool(t2, i2, output_size=c2.size()), c2), dim=1)
        t1 = self.Tconv2(z2)
        
        z1 = torch.cat((self.max_unpool(t1, i1, output_size=c1.size()), c1), dim=1)
        out = self.Tconv1(z1)
        
        return self.softmax(out)

# %%
model = Network()
print(torchinfo.summary(model, (1,3, 256, 256)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Network                                  [1, 5, 256, 256]          --
# ├─Sequential: 1-1                        [1, 64, 252, 252]         --
# │    └─Conv2d: 2-1                       [1, 64, 254, 254]         1,792
# │    └─ReLU: 2-2                         [1, 64, 254, 254]         --
# │    └─Conv2d: 2-3                       [1, 64, 252, 252]         36,928
# │    └─ReLU: 2-4                         [1, 64, 252, 252]         --
# │    └─BatchNorm2d: 2-5                  [1, 64, 252, 252]         128
# ├─MaxPool2d: 1-2                         [1, 64, 126, 126]         --
# ├─Sequential: 1-3                        [1, 128, 122, 122]        --
# │    └─Conv2d: 2-6                       [1, 128, 124, 124]        73,856
# │    └─ReLU: 2-7                         [1, 128, 124, 124]        --
# │    └─Conv2d: 2-8                       [1, 128, 122, 122]        147,584
# │    └─ReLU: 2-9                         [1, 128, 122, 122]        --
# │    └─BatchNorm2d: 2-10                 [1, 128, 122, 122]        256
# ├─MaxPool2d: 1-4                         [1, 128, 61, 61]          --
# ├─Sequential: 1-5                        [1, 256, 57, 57]          --
# │    └─Conv2d: 2-11                      [1, 256, 59, 59]          295,168
# │    └─ReLU: 2-12                        [1, 256, 59, 59]          --
# │    └─Conv2d: 2-13                      [1, 256, 57, 57]          590,080
# │    └─ReLU: 2-14                        [1, 256, 57, 57]          --
# │    └─BatchNorm2d: 2-15                 [1, 256, 57, 57]          512
# ├─MaxPool2d: 1-6                         [1, 256, 28, 28]          --
# ├─Sequential: 1-7                        [1, 512, 24, 24]          --
# │    └─Conv2d: 2-16                      [1, 512, 26, 26]          1,180,160
# │    └─ReLU: 2-17                        [1, 512, 26, 26]          --
# │    └─Conv2d: 2-18                      [1, 512, 24, 24]          2,359,808
# │    └─ReLU: 2-19                        [1, 512, 24, 24]          --
# │    └─BatchNorm2d: 2-20                 [1, 512, 24, 24]          1,024
# ├─MaxPool2d: 1-8                         [1, 512, 12, 12]          --
# ├─Sequential: 1-9                        [1, 1024, 8, 8]           --
# │    └─Conv2d: 2-21                      [1, 1024, 10, 10]         4,719,616
# │    └─ReLU: 2-22                        [1, 1024, 10, 10]         --
# │    └─Conv2d: 2-23                      [1, 1024, 8, 8]           9,438,208
# │    └─ReLU: 2-24                        [1, 1024, 8, 8]           --
# │    └─BatchNorm2d: 2-25                 [1, 1024, 8, 8]           2,048
# ├─Dropout2d: 1-10                        [1, 1024, 8, 8]           --
# ├─Sequential: 1-11                       [1, 512, 12, 12]          --
# │    └─ConvTranspose2d: 2-26             [1, 512, 10, 10]          4,719,104
# │    └─ReLU: 2-27                        [1, 512, 10, 10]          --
# │    └─ConvTranspose2d: 2-28             [1, 512, 12, 12]          2,359,808
# │    └─ReLU: 2-29                        [1, 512, 12, 12]          --
# │    └─BatchNorm2d: 2-30                 [1, 512, 12, 12]          1,024
# ├─MaxUnpool2d: 1-12                      [1, 512, 24, 24]          --
# ├─Sequential: 1-13                       [1, 256, 28, 28]          --
# │    └─ConvTranspose2d: 2-31             [1, 256, 26, 26]          2,359,552
# │    └─ReLU: 2-32                        [1, 256, 26, 26]          --
# │    └─ConvTranspose2d: 2-33             [1, 256, 28, 28]          590,080
# │    └─ReLU: 2-34                        [1, 256, 28, 28]          --
# │    └─BatchNorm2d: 2-35                 [1, 256, 28, 28]          512
# ├─MaxUnpool2d: 1-14                      [1, 256, 57, 57]          --
# ├─Sequential: 1-15                       [1, 128, 61, 61]          --
# │    └─ConvTranspose2d: 2-36             [1, 128, 59, 59]          589,952
# │    └─ReLU: 2-37                        [1, 128, 59, 59]          --
# │    └─ConvTranspose2d: 2-38             [1, 128, 61, 61]          147,584
# │    └─ReLU: 2-39                        [1, 128, 61, 61]          --
# │    └─BatchNorm2d: 2-40                 [1, 128, 61, 61]          256
# ├─MaxUnpool2d: 1-16                      [1, 128, 122, 122]        --
# ├─Sequential: 1-17                       [1, 64, 126, 126]         --
# │    └─ConvTranspose2d: 2-41             [1, 64, 124, 124]         147,520
# │    └─ReLU: 2-42                        [1, 64, 124, 124]         --
# │    └─ConvTranspose2d: 2-43             [1, 64, 126, 126]         36,928
# │    └─ReLU: 2-44                        [1, 64, 126, 126]         --
# │    └─BatchNorm2d: 2-45                 [1, 64, 126, 126]         128
# ├─MaxUnpool2d: 1-18                      [1, 64, 252, 252]         --
# ├─Sequential: 1-19                       [1, 5, 256, 256]          --
# │    └─ConvTranspose2d: 2-46             [1, 5, 254, 254]          5,765
# │    └─ReLU: 2-47                        [1, 5, 254, 254]          --
# │    └─ConvTranspose2d: 2-48             [1, 5, 256, 256]          230
# │    └─ReLU: 2-49                        [1, 5, 256, 256]          --
# │    └─BatchNorm2d: 2-50                 [1, 5, 256, 256]          10
# ├─Softmax: 1-20                          [1, 5, 256, 256]          --
# ==========================================================================================
# Total params: 29,805,621
# Trainable params: 29,805,621
# Non-trainable params: 0
# Total mult-adds (G): 20.68
# ==========================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 223.40
# Params size (MB): 119.22
# Estimated Total Size (MB): 343.41
# ==========================================================================================

# %%
#Hyperparameters:
epochs = 150
batch_size = 16
lr = 1e-2
momentum = 0.9
weights = torch.tensor([0.0621, 0.0093, 0.0101, 0.9022, 0.0163]).to(device) * 5

# %%
model = model.to(device)
loss_fn = nn.CrossEntropyLoss(weight=weights)
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum)

train_size = len(train)
val_size = len(val)
num_train_batches = train_size/batch_size
num_val_batches = val_size/batch_size

print(f'Epochs : {epochs}')
print(f'Batch size : {batch_size}')
print(f'Learning rate : {lr}')
print(f'Momentum : {momentum}')
print(f'Training with {train_size} images')
print(f'Validation with {val_size} images')
print(f'Number of training minibatches = {int(num_train_batches)} per epoch')
print(f'Number of validation minibatches = {int(num_val_batches)} per epoch')

trainloader = DataLoader(train, batch_size=batch_size, shuffle=True)
valloader = DataLoader(val, batch_size=batch_size, shuffle=True)

hist = {'train_loss':[], 
        'val_loss':[],
        'train_acc': [],
        'val_acc': []}

for epoch in range(epochs):
    print(f'{"-"*30}Epoch {epoch+1}/{epochs}{"-"*30}')
    
    total_train_loss = 0
    total_val_loss = 0
    total_train_acc = 0
    total_val_acc = 0
    
    #Training Loop
    model.train()
    for batch, (x,y) in enumerate(trainloader):
        x,y = x.to(device), y.to(device)
        x = x/255
        #Forward prop
        preds = model(x)
        loss = loss_fn(preds, y)
        total_train_loss += loss.item()
        total_train_acc += acc(preds, y).cpu()
        
        #Backprop
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    #Validation loop
    model.eval()
    with torch.no_grad():
        for batch, (x,y) in enumerate(valloader):
            x,y = x.to(device), y.to(device)
            x=x/255
            #Inference
            preds = model(x)
            loss = loss_fn(preds, y)
            total_val_loss += loss.item()
            total_val_acc += acc(preds, y).cpu()
    
    
    avg_train_loss = total_train_loss / num_train_batches
    avg_val_loss = total_val_loss / num_val_batches
    avg_train_acc = total_train_acc / num_train_batches
    avg_val_acc = total_val_acc / num_val_batches
    
    print(f"Training Loss    : {avg_train_loss:<7f}      Training Accuracy    : {avg_train_acc:<7f}")
    print(f"Validation Loss  : {avg_val_loss:<7f}     Validation Accuracy  : {avg_val_acc:<7f}")
    
    hist['train_loss'].append(avg_train_loss)
    hist['train_acc'].append(avg_train_acc)
    hist['val_loss'].append(avg_val_loss)
    hist['val_acc'].append(avg_val_acc)
# Out:
# Epochs : 150
# Batch size : 16
# Learning rate : 0.01
# Momentum : 0.9
# Training with 5287 images
# Validation with 1321 images
# Number of training minibatches = 330 per epoch
# Number of validation minibatches = 82 per epoch
# ------------------------------Epoch 1/150------------------------------
# Training Loss    : 0.028081      Training Accuracy    : 0.000000
# Validation Loss  : 0.029000     Validation Accuracy  : 0.000000
# ------------------------------Epoch 2/150------------------------------
# Training Loss    : 0.027919      Training Accuracy    : 0.000000
# Validation Loss  : 0.028954     Validation Accuracy  : 0.000000
# ------------------------------Epoch 3/150------------------------------
# Training Loss    : 0.027943      Training Accuracy    : 0.000000
# Validation Loss  : 0.028977     Validation Accuracy  : 0.000000
# ------------------------------Epoch 4/150------------------------------
# Training Loss    : 0.027871      Training Accuracy    : 0.000000
# Validation Loss  : 0.029000     Validation Accuracy  : 0.000000
# ------------------------------Epoch 5/150------------------------------
# Training Loss    : 0.027821      Training Accuracy    : 0.000000
# Validation Loss  : 0.028995     Validation Accuracy  : 0.000000
# ------------------------------Epoch 6/150------------------------------
# Training Loss    : 0.027763      Training Accuracy    : 0.000000
# Validation Loss  : 0.028921     Validation Accuracy  : 0.000000
# ------------------------------Epoch 7/150------------------------------
# Training Loss    : 0.027753      Training Accuracy    : 0.000000
# Validation Loss  : 0.029109     Validation Accuracy  : 0.000000
# ------------------------------Epoch 8/150------------------------------
# Training Loss    : 0.027769      Training Accuracy    : 0.000000
# Validation Loss  : 0.028956     Validation Accuracy  : 0.000000
# ------------------------------Epoch 9/150------------------------------
# Training Loss    : 0.027799      Training Accuracy    : 0.000000
# Validation Loss  : 0.028870     Validation Accuracy  : 0.000000
# ------------------------------Epoch 10/150------------------------------
# Training Loss    : 0.027879      Training Accuracy    : 0.000000
# Validation Loss  : 0.029007     Validation Accuracy  : 0.000000
# ------------------------------Epoch 11/150------------------------------
# Training Loss    : 0.027736      Training Accuracy    : 0.000000
# Validation Loss  : 0.029038     Validation Accuracy  : 0.000000
# ------------------------------Epoch 12/150------------------------------
# Training Loss    : 0.027730      Training Accuracy    : 0.000000
# Validation Loss  : 0.029030     Validation Accuracy  : 0.000000
# ------------------------------Epoch 13/150------------------------------
# Training Loss    : 0.027690      Training Accuracy    : 0.000000
# Validation Loss  : 0.028907     Validation Accuracy  : 0.000000
# ------------------------------Epoch 14/150------------------------------
# Training Loss    : 0.027733      Training Accuracy    : 0.000000
# Validation Loss  : 0.028889     Validation Accuracy  : 0.000000
# ------------------------------Epoch 15/150------------------------------
# Training Loss    : 0.027731      Training Accuracy    : 0.000000
# Validation Loss  : 0.028822     Validation Accuracy  : 0.000000
# ------------------------------Epoch 16/150------------------------------
# Training Loss    : 0.027654      Training Accuracy    : 0.000000
# Validation Loss  : 0.028828     Validation Accuracy  : 0.000000
# ------------------------------Epoch 17/150------------------------------
# Training Loss    : 0.027646      Training Accuracy    : 0.000000
# Validation Loss  : 0.028848     Validation Accuracy  : 0.000000
# ------------------------------Epoch 18/150------------------------------
# Training Loss    : 0.027645      Training Accuracy    : 0.000000
# Validation Loss  : 0.028936     Validation Accuracy  : 0.000000
# ------------------------------Epoch 19/150------------------------------
# Training Loss    : 0.027662      Training Accuracy    : 0.000000
# Validation Loss  : 0.029034     Validation Accuracy  : 0.000000
# ------------------------------Epoch 20/150------------------------------
# Training Loss    : 0.027724      Training Accuracy    : 0.000000
# Validation Loss  : 0.028770     Validation Accuracy  : 0.000000
# ------------------------------Epoch 21/150------------------------------
# Training Loss    : 0.027579      Training Accuracy    : 0.000000
# Validation Loss  : 0.029571     Validation Accuracy  : 0.000000
# ------------------------------Epoch 22/150------------------------------
# Training Loss    : 0.027665      Training Accuracy    : 0.000000
# Validation Loss  : 0.028604     Validation Accuracy  : 0.000000
# ------------------------------Epoch 23/150------------------------------
# Training Loss    : 0.027547      Training Accuracy    : 0.000000
# Validation Loss  : 0.029049     Validation Accuracy  : 0.000000
# ------------------------------Epoch 24/150------------------------------
# Training Loss    : 0.027752      Training Accuracy    : 0.000000
# Validation Loss  : 0.028927     Validation Accuracy  : 0.000001
# ------------------------------Epoch 25/150------------------------------
# Training Loss    : 0.027635      Training Accuracy    : 0.000000
# Validation Loss  : 0.028821     Validation Accuracy  : 0.000000
# ------------------------------Epoch 26/150------------------------------
# Training Loss    : 0.027591      Training Accuracy    : 0.000000
# Validation Loss  : 0.028818     Validation Accuracy  : 0.000000
# ------------------------------Epoch 27/150------------------------------
# Training Loss    : 0.027556      Training Accuracy    : 0.000000
# Validation Loss  : 0.028781     Validation Accuracy  : 0.000000
# ------------------------------Epoch 28/150------------------------------
# Training Loss    : 0.027482      Training Accuracy    : 0.000000
# Validation Loss  : 0.028647     Validation Accuracy  : 0.000000
# ------------------------------Epoch 29/150------------------------------
# Training Loss    : 0.027502      Training Accuracy    : 0.000000
# Validation Loss  : 0.028919     Validation Accuracy  : 0.000000
# ------------------------------Epoch 30/150------------------------------
# Training Loss    : 0.027623      Training Accuracy    : 0.000000
# Validation Loss  : 0.028985     Validation Accuracy  : 0.000000
# ------------------------------Epoch 31/150------------------------------
# Training Loss    : 0.027582      Training Accuracy    : 0.000000
# Validation Loss  : 0.029008     Validation Accuracy  : 0.000000
# ------------------------------Epoch 32/150------------------------------
# Training Loss    : 0.027499      Training Accuracy    : 0.000000
# Validation Loss  : 0.028614     Validation Accuracy  : 0.000000
# ------------------------------Epoch 33/150------------------------------
# Training Loss    : 0.027474      Training Accuracy    : 0.000000
# Validation Loss  : 0.028849     Validation Accuracy  : 0.000000
# ------------------------------Epoch 34/150------------------------------
# Training Loss    : 0.027519      Training Accuracy    : 0.000000
# Validation Loss  : 0.028643     Validation Accuracy  : 0.000000
# ------------------------------Epoch 35/150------------------------------
# Training Loss    : 0.027410      Training Accuracy    : 0.000000
# Validation Loss  : 0.028742     Validation Accuracy  : 0.000000
# ------------------------------Epoch 36/150------------------------------
# Training Loss    : 0.027465      Training Accuracy    : 0.000000
# Validation Loss  : 0.028660     Validation Accuracy  : 0.000000
# ------------------------------Epoch 37/150------------------------------
# Training Loss    : 0.027433      Training Accuracy    : 0.000000
# Validation Loss  : 0.028764     Validation Accuracy  : 0.000000
# ------------------------------Epoch 38/150------------------------------
# Training Loss    : 0.027508      Training Accuracy    : 0.000000
# Validation Loss  : 0.028907     Validation Accuracy  : 0.000000
# ------------------------------Epoch 39/150------------------------------
# Training Loss    : 0.027434      Training Accuracy    : 0.000000
# Validation Loss  : 0.028408     Validation Accuracy  : 0.000000
# ------------------------------Epoch 40/150------------------------------
# Training Loss    : 0.027505      Training Accuracy    : 0.000000
# Validation Loss  : 0.028495     Validation Accuracy  : 0.000000
# ------------------------------Epoch 41/150------------------------------
# Training Loss    : 0.027475      Training Accuracy    : 0.000000
# Validation Loss  : 0.028452     Validation Accuracy  : 0.000000
# ------------------------------Epoch 42/150------------------------------
# Training Loss    : 0.027284      Training Accuracy    : 0.000000
# Validation Loss  : 0.028586     Validation Accuracy  : 0.000000
# ------------------------------Epoch 43/150------------------------------
# Training Loss    : 0.027331      Training Accuracy    : 0.000000
# Validation Loss  : 0.028819     Validation Accuracy  : 0.000000
# ------------------------------Epoch 44/150------------------------------
# Training Loss    : 0.027347      Training Accuracy    : 0.000000
# Validation Loss  : 0.028711     Validation Accuracy  : 0.000000
# ------------------------------Epoch 45/150------------------------------
# Training Loss    : 0.027278      Training Accuracy    : 0.000000
# Validation Loss  : 0.028789     Validation Accuracy  : 0.000000
# ------------------------------Epoch 46/150------------------------------
# Training Loss    : 0.027230      Training Accuracy    : 0.000000
# Validation Loss  : 0.028710     Validation Accuracy  : 0.000000
# ------------------------------Epoch 47/150------------------------------
# Training Loss    : 0.027312      Training Accuracy    : 0.000000
# Validation Loss  : 0.028570     Validation Accuracy  : 0.000000
# ------------------------------Epoch 48/150------------------------------
# Training Loss    : 0.027226      Training Accuracy    : 0.000000
# Validation Loss  : 0.028442     Validation Accuracy  : 0.000000
# ------------------------------Epoch 49/150------------------------------
# Training Loss    : 0.027361      Training Accuracy    : 0.000000
# Validation Loss  : 0.028567     Validation Accuracy  : 0.000000
# ------------------------------Epoch 50/150------------------------------
# Training Loss    : 0.027203      Training Accuracy    : 0.000000
# Validation Loss  : 0.028743     Validation Accuracy  : 0.000000
# ------------------------------Epoch 51/150------------------------------
# Training Loss    : 0.027214      Training Accuracy    : 0.000000
# Validation Loss  : 0.028394     Validation Accuracy  : 0.000000
# ------------------------------Epoch 52/150------------------------------
# Training Loss    : 0.027207      Training Accuracy    : 0.000000
# Validation Loss  : 0.028564     Validation Accuracy  : 0.000000
# ------------------------------Epoch 53/150------------------------------
# Training Loss    : 0.027203      Training Accuracy    : 0.000000
# Validation Loss  : 0.028454     Validation Accuracy  : 0.000000
# ------------------------------Epoch 54/150------------------------------
# Training Loss    : 0.027216      Training Accuracy    : 0.000000
# Validation Loss  : 0.028481     Validation Accuracy  : 0.000000
# ------------------------------Epoch 55/150------------------------------
# Training Loss    : 0.027278      Training Accuracy    : 0.000000
# Validation Loss  : 0.028625     Validation Accuracy  : 0.000000
# ------------------------------Epoch 56/150------------------------------
# Training Loss    : 0.027087      Training Accuracy    : 0.000000
# Validation Loss  : 0.028410     Validation Accuracy  : 0.000000
# ------------------------------Epoch 57/150------------------------------
# Training Loss    : 0.027226      Training Accuracy    : 0.000000
# Validation Loss  : 0.028284     Validation Accuracy  : 0.000000
# ------------------------------Epoch 58/150------------------------------
# Training Loss    : 0.027221      Training Accuracy    : 0.000000
# Validation Loss  : 0.028722     Validation Accuracy  : 0.000000
# ------------------------------Epoch 59/150------------------------------
# Training Loss    : 0.027103      Training Accuracy    : 0.000000
# Validation Loss  : 0.028420     Validation Accuracy  : 0.000000
# ------------------------------Epoch 60/150------------------------------
# Training Loss    : 0.027073      Training Accuracy    : 0.000000
# Validation Loss  : 0.028387     Validation Accuracy  : 0.000000
# ------------------------------Epoch 61/150------------------------------
# Training Loss    : 0.026991      Training Accuracy    : 0.000000
# Validation Loss  : 0.028210     Validation Accuracy  : 0.000000
# ------------------------------Epoch 62/150------------------------------
# Training Loss    : 0.027097      Training Accuracy    : 0.000000
# Validation Loss  : 0.028244     Validation Accuracy  : 0.000000
# ------------------------------Epoch 63/150------------------------------
# Training Loss    : 0.026968      Training Accuracy    : 0.000000
# Validation Loss  : 0.028192     Validation Accuracy  : 0.000000
# ------------------------------Epoch 64/150------------------------------
# Training Loss    : 0.027132      Training Accuracy    : 0.000000
# Validation Loss  : 0.028355     Validation Accuracy  : 0.000000
# ------------------------------Epoch 65/150------------------------------
# Training Loss    : 0.027082      Training Accuracy    : 0.000000
# Validation Loss  : 0.028415     Validation Accuracy  : 0.000000
# ------------------------------Epoch 66/150------------------------------
# Training Loss    : 0.027094      Training Accuracy    : 0.000000
# Validation Loss  : 0.028358     Validation Accuracy  : 0.000000
# ------------------------------Epoch 67/150------------------------------
# Training Loss    : 0.026985      Training Accuracy    : 0.000000
# Validation Loss  : 0.028302     Validation Accuracy  : 0.000000
# ------------------------------Epoch 68/150------------------------------
# Training Loss    : 0.026975      Training Accuracy    : 0.000000
# Validation Loss  : 0.028172     Validation Accuracy  : 0.000000
# ------------------------------Epoch 69/150------------------------------
# Training Loss    : 0.026988      Training Accuracy    : 0.000000
# Validation Loss  : 0.028250     Validation Accuracy  : 0.000000
# ------------------------------Epoch 70/150------------------------------
# Training Loss    : 0.026834      Training Accuracy    : 0.000000
# Validation Loss  : 0.028763     Validation Accuracy  : 0.000000
# ------------------------------Epoch 71/150------------------------------
# Training Loss    : 0.026970      Training Accuracy    : 0.000000
# Validation Loss  : 0.028226     Validation Accuracy  : 0.000000
# ------------------------------Epoch 72/150------------------------------
# Training Loss    : 0.027087      Training Accuracy    : 0.000000
# Validation Loss  : 0.028621     Validation Accuracy  : 0.000000
# ------------------------------Epoch 73/150------------------------------
# Training Loss    : 0.026982      Training Accuracy    : 0.000000
# Validation Loss  : 0.028050     Validation Accuracy  : 0.000000
# ------------------------------Epoch 74/150------------------------------
# Training Loss    : 0.027047      Training Accuracy    : 0.000000
# Validation Loss  : 0.028098     Validation Accuracy  : 0.000000
# ------------------------------Epoch 75/150------------------------------
# Training Loss    : 0.026872      Training Accuracy    : 0.000000
# Validation Loss  : 0.028128     Validation Accuracy  : 0.000000
# ------------------------------Epoch 76/150------------------------------
# Training Loss    : 0.026895      Training Accuracy    : 0.000000
# Validation Loss  : 0.028082     Validation Accuracy  : 0.000000
# ------------------------------Epoch 77/150------------------------------
# Training Loss    : 0.026856      Training Accuracy    : 0.000000
# Validation Loss  : 0.028393     Validation Accuracy  : 0.000000
# ------------------------------Epoch 78/150------------------------------
# Training Loss    : 0.026888      Training Accuracy    : 0.000000
# Validation Loss  : 0.028713     Validation Accuracy  : 0.000000
# ------------------------------Epoch 79/150------------------------------
# Training Loss    : 0.026825      Training Accuracy    : 0.000000
# Validation Loss  : 0.028042     Validation Accuracy  : 0.000000
# ------------------------------Epoch 80/150------------------------------
# Training Loss    : 0.026937      Training Accuracy    : 0.000000
# Validation Loss  : 0.028230     Validation Accuracy  : 0.000000
# ------------------------------Epoch 81/150------------------------------
# Training Loss    : 0.026810      Training Accuracy    : 0.000000
# Validation Loss  : 0.028249     Validation Accuracy  : 0.000000
# ------------------------------Epoch 82/150------------------------------
# Training Loss    : 0.026836      Training Accuracy    : 0.000000
# Validation Loss  : 0.028057     Validation Accuracy  : 0.000000
# ------------------------------Epoch 83/150------------------------------
# Training Loss    : 0.026846      Training Accuracy    : 0.000000
# Validation Loss  : 0.028103     Validation Accuracy  : 0.000000
# ------------------------------Epoch 84/150------------------------------
# Training Loss    : 0.026772      Training Accuracy    : 0.000000
# Validation Loss  : 0.028060     Validation Accuracy  : 0.000000
# ------------------------------Epoch 85/150------------------------------
# Training Loss    : 0.026828      Training Accuracy    : 0.000000
# Validation Loss  : 0.028108     Validation Accuracy  : 0.000000
# ------------------------------Epoch 86/150------------------------------
# Training Loss    : 0.026741      Training Accuracy    : 0.000000
# Validation Loss  : 0.028012     Validation Accuracy  : 0.000000
# ------------------------------Epoch 87/150------------------------------
# Training Loss    : 0.026838      Training Accuracy    : 0.000000
# Validation Loss  : 0.028091     Validation Accuracy  : 0.000000
# ------------------------------Epoch 88/150------------------------------
# Training Loss    : 0.026837      Training Accuracy    : 0.000000
# Validation Loss  : 0.028112     Validation Accuracy  : 0.000000
# ------------------------------Epoch 89/150------------------------------
# Training Loss    : 0.026905      Training Accuracy    : 0.000000
# Validation Loss  : 0.028036     Validation Accuracy  : 0.000000
# ------------------------------Epoch 90/150------------------------------
# Training Loss    : 0.026946      Training Accuracy    : 0.000000
# Validation Loss  : 0.028083     Validation Accuracy  : 0.000000
# ------------------------------Epoch 91/150------------------------------
# Training Loss    : 0.026813      Training Accuracy    : 0.000000
# Validation Loss  : 0.028235     Validation Accuracy  : 0.000000
# ------------------------------Epoch 92/150------------------------------
# Training Loss    : 0.026753      Training Accuracy    : 0.000000
# Validation Loss  : 0.027959     Validation Accuracy  : 0.000000
# ------------------------------Epoch 93/150------------------------------
# Training Loss    : 0.026674      Training Accuracy    : 0.000000
# Validation Loss  : 0.028501     Validation Accuracy  : 0.000000
# ------------------------------Epoch 94/150------------------------------
# Training Loss    : 0.026731      Training Accuracy    : 0.000000
# Validation Loss  : 0.028166     Validation Accuracy  : 0.000000
# ------------------------------Epoch 95/150------------------------------
# Training Loss    : 0.026720      Training Accuracy    : 0.000000
# Validation Loss  : 0.027980     Validation Accuracy  : 0.000000
# ------------------------------Epoch 96/150------------------------------
# Training Loss    : 0.026871      Training Accuracy    : 0.000000
# Validation Loss  : 0.028659     Validation Accuracy  : 0.000000
# ------------------------------Epoch 97/150------------------------------
# Training Loss    : 0.026854      Training Accuracy    : 0.000000
# Validation Loss  : 0.028045     Validation Accuracy  : 0.000000
# ------------------------------Epoch 98/150------------------------------
# Training Loss    : 0.026913      Training Accuracy    : 0.000000
# Validation Loss  : 0.028034     Validation Accuracy  : 0.000000
# ------------------------------Epoch 99/150------------------------------
# Training Loss    : 0.026827      Training Accuracy    : 0.000000
# Validation Loss  : 0.028173     Validation Accuracy  : 0.000000
# ------------------------------Epoch 100/150------------------------------
# Training Loss    : 0.026738      Training Accuracy    : 0.000000
# Validation Loss  : 0.027953     Validation Accuracy  : 0.000000
# ------------------------------Epoch 101/150------------------------------
# Training Loss    : 0.026802      Training Accuracy    : 0.000000
# Validation Loss  : 0.027975     Validation Accuracy  : 0.000000
# ------------------------------Epoch 102/150------------------------------
# Training Loss    : 0.026832      Training Accuracy    : 0.000000
# Validation Loss  : 0.027947     Validation Accuracy  : 0.000000
# ------------------------------Epoch 103/150------------------------------
# Training Loss    : 0.026807      Training Accuracy    : 0.000000
# Validation Loss  : 0.028521     Validation Accuracy  : 0.000000
# ------------------------------Epoch 104/150------------------------------
# Training Loss    : 0.026864      Training Accuracy    : 0.000000
# Validation Loss  : 0.028121     Validation Accuracy  : 0.000000
# ------------------------------Epoch 105/150------------------------------

# %%
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(hist['train_loss'], label='Training Loss')
plt.plot(hist['val_loss'], label='Validation Loss')
plt.legend()
plt.savefig(f'{trn_hist_path}/loss_curve.png')

# %%
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.plot(hist['train_acc'], label='Training Accuracy')
plt.plot(hist['val_acc'], label='Validation Accuracy')
plt.legend()
plt.savefig(f'{trn_hist_path}/acc_curve.png')

# %%
print('Images from the validation set')
idx = torch.randint(0, val_size, (3,))
model.to('cpu')
model.eval()
for i in (idx):
    img, label = val.__getitem__(i)
    visualize_sample(img, label, f'Ground Truth {i}', path = val_out_path)
    visualize_predictions(model, img, i, val_out_path)

# %%
print('Images from the training set')
idx = torch.randint(0, train_size, (3,))
model.to('cpu')
model.eval()
for i in (idx):
    img, label = train.__getitem__(i)
    visualize_sample(img, label, f'Ground Truth {i}', trn_out_path)
    visualize_predictions(model, img, i, trn_out_path)
