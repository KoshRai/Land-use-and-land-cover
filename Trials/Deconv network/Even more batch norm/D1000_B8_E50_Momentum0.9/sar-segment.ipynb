# %%
# !pip install torchinfo
# !pip install torchmetrics
# !pip install torchsummary

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# from google.colab.patches import cv2_imshow as imshow

# %%
# !unzip "/content/gdrive/MyDrive/Dataset.zip" -d "/content/gdrive/MyDrive/SAR_Dataset"

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import os
import torchinfo

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
class SARData(Dataset):
    def __init__(self):
        
        self.xtrain_path = '/kaggle/input/sar8bit/Dataset/img_dir'
        self.ytrain_path = '/kaggle/input/sar8bit/Dataset/ann_dir_8bit'
        self.xtrain_imgs = np.array(os.listdir(self.xtrain_path))[:1000]
        self.ytrain_imgs = np.array(os.listdir(self.ytrain_path))[:1000]
        self.num_classes = 5
        self.height, self.width = 256,256

    def process_label(self, label):
        r = []
        for i in range(self.num_classes):
            mask = label == i+1
            mask = mask.float()
            r.append(mask)
        return torch.stack(r)
    
    def __len__(self):
        return len(self.ytrain_imgs)
    
    def __getitem__(self, idx):        
        xtrain = cv.imread(f"{self.xtrain_path}/{self.xtrain_imgs[idx]}")
        xtrain = cv.cvtColor(xtrain, cv.COLOR_BGR2RGB)
        xtrain = torch.tensor(xtrain).permute(2,0,1) #HWC -> CHW
        
        ytrain = cv.imread(f"{self.ytrain_path}/{self.ytrain_imgs[idx]}", cv.IMREAD_GRAYSCALE)
        ytrain = torch.tensor(ytrain)
        processed_ytrain = self.process_label(ytrain)
        
        
        return xtrain, processed_ytrain

# %%
def visualize_sample(img, label):
    fig, ax = plt.subplots(1, 6, figsize=(20,20)) 
    for i, subplot_ax in zip(range(data.num_classes + 1), ax.flatten()):
        if i == 0: 
            subplot_ax.imshow(img.permute(1,2,0))
            subplot_ax.set_title(f'Training Sample')
        else:
            subplot_ax.imshow(label[i-1], cmap='gray', vmin=0, vmax=1)
            subplot_ax.set_title(f'Label {i}')

def visualize_predictions(model, img):
    inp = (img - 127.5) / 255
    inp = torch.unsqueeze(inp, dim=0)
    pred = model(inp)
    visualize_sample(img, pred.squeeze().detach().numpy())

# %%
data = SARData()
idx = (torch.randint(0, 1000, (5,)))

for i in idx:
    img, label = data.__getitem__(i)
    visualize_sample(img, label)

# %%
def double_conv(in_channels, out_channels):
    conv = nn.Sequential(
        nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU()
    )
    return conv

def double_Tconv(in_channels, out_channels):
    Tconv = nn.Sequential(
        nn.ConvTranspose2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.ConvTranspose2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU()
    )
    return Tconv

class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2, return_indices=True)
        self.max_unpool = nn.MaxUnpool2d(kernel_size=2, stride=2)
        self.conv1 = double_conv(3, 64)
        self.conv2 = double_conv(64, 128)
        self.conv3 = double_conv(128, 256)
        self.conv4 = double_conv(256, 512)
        self.conv5 = double_conv(512, 1024)
        self.Tconv5 = double_Tconv(1024, 512)
        self.Tconv4 = double_Tconv(512, 256)
        self.Tconv3 = double_Tconv(256, 128)
        self.Tconv2 = double_Tconv(128, 64)
        self.Tconv1 = double_Tconv(64, 5)
        self.bn1 = nn.BatchNorm2d(64)
        self.bn2 = nn.BatchNorm2d(128)
        self.bn3 = nn.BatchNorm2d(256)
        self.bn4 = nn.BatchNorm2d(512)
        self.bn4u = nn.BatchNorm2d(512)
        self.bn3u = nn.BatchNorm2d(256)
        self.bn2u = nn.BatchNorm2d(128)
        self.bn1u = nn.BatchNorm2d(64)
        self.softmax = nn.Softmax(dim=1)
    
    def forward(self, x):
        c1 = self.conv1(x)
        c1 = self.bn1(c1)
        x1, i1 = self.max_pool(c1)

        c2 = self.conv2(x1)
        c2 - self.bn2(c2)
        x2, i2 = self.max_pool(c2)
        
        c3 = self.conv3(x2)
        c3 = self.bn3(c3)
        x3, i3 = self.max_pool(c3)

        c4 = self.conv4(x3)
        c4 = self.bn4(c4)
        x4, i4 = self.max_pool(c4)
        
        i = self.conv5(x4)
        
        t4 = self.Tconv5(i)
        
        t4 = self.bn4u(t4)
        z4 = self.max_unpool(t4, i4, output_size=c4.size())
        t3 = self.Tconv4(z4)
        
        t3 = self.bn3u(t3)
        z3 = self.max_unpool(t3, i3, output_size=c3.size())
        t2 = self.Tconv3(z3)
        
        t2 = self.bn2u(t2)
        z2 = self.max_unpool(t2, i2, output_size=c2.size())
        t1 = self.Tconv2(z2)
        
        t1 = self.bn1u(t1)
        z1 = self.max_unpool(t1, i1, output_size=c1.size())
        out = self.Tconv1(z1)
        
        return self.softmax(out)

# %%
model = Network()
# model.eval()
torchinfo.summary(model, (1,3,256,256))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Network                                  [1, 5, 256, 256]          --
# ├─Sequential: 1-1                        [1, 64, 252, 252]         --
# │    └─Conv2d: 2-1                       [1, 64, 254, 254]         1,792
# │    └─ReLU: 2-2                         [1, 64, 254, 254]         --
# │    └─Conv2d: 2-3                       [1, 64, 252, 252]         36,928
# │    └─ReLU: 2-4                         [1, 64, 252, 252]         --
# ├─BatchNorm2d: 1-2                       [1, 64, 252, 252]         128
# ├─MaxPool2d: 1-3                         [1, 64, 126, 126]         --
# ├─Sequential: 1-4                        [1, 128, 122, 122]        --
# │    └─Conv2d: 2-5                       [1, 128, 124, 124]        73,856
# │    └─ReLU: 2-6                         [1, 128, 124, 124]        --
# │    └─Conv2d: 2-7                       [1, 128, 122, 122]        147,584
# │    └─ReLU: 2-8                         [1, 128, 122, 122]        --
# ├─BatchNorm2d: 1-5                       [1, 128, 122, 122]        256
# ├─MaxPool2d: 1-6                         [1, 128, 61, 61]          --
# ├─Sequential: 1-7                        [1, 256, 57, 57]          --
# │    └─Conv2d: 2-9                       [1, 256, 59, 59]          295,168
# │    └─ReLU: 2-10                        [1, 256, 59, 59]          --
# │    └─Conv2d: 2-11                      [1, 256, 57, 57]          590,080
# │    └─ReLU: 2-12                        [1, 256, 57, 57]          --
# ├─BatchNorm2d: 1-8                       [1, 256, 57, 57]          512
# ├─MaxPool2d: 1-9                         [1, 256, 28, 28]          --
# ├─Sequential: 1-10                       [1, 512, 24, 24]          --
# │    └─Conv2d: 2-13                      [1, 512, 26, 26]          1,180,160
# │    └─ReLU: 2-14                        [1, 512, 26, 26]          --
# │    └─Conv2d: 2-15                      [1, 512, 24, 24]          2,359,808
# │    └─ReLU: 2-16                        [1, 512, 24, 24]          --
# ├─BatchNorm2d: 1-11                      [1, 512, 24, 24]          1,024
# ├─MaxPool2d: 1-12                        [1, 512, 12, 12]          --
# ├─Sequential: 1-13                       [1, 1024, 8, 8]           --
# │    └─Conv2d: 2-17                      [1, 1024, 10, 10]         4,719,616
# │    └─ReLU: 2-18                        [1, 1024, 10, 10]         --
# │    └─Conv2d: 2-19                      [1, 1024, 8, 8]           9,438,208
# │    └─ReLU: 2-20                        [1, 1024, 8, 8]           --
# ├─Sequential: 1-14                       [1, 512, 12, 12]          --
# │    └─ConvTranspose2d: 2-21             [1, 512, 10, 10]          4,719,104
# │    └─ReLU: 2-22                        [1, 512, 10, 10]          --
# │    └─ConvTranspose2d: 2-23             [1, 512, 12, 12]          2,359,808
# │    └─ReLU: 2-24                        [1, 512, 12, 12]          --
# ├─BatchNorm2d: 1-15                      [1, 512, 12, 12]          1,024
# ├─MaxUnpool2d: 1-16                      [1, 512, 24, 24]          --
# ├─Sequential: 1-17                       [1, 256, 28, 28]          --
# │    └─ConvTranspose2d: 2-25             [1, 256, 26, 26]          1,179,904
# │    └─ReLU: 2-26                        [1, 256, 26, 26]          --
# │    └─ConvTranspose2d: 2-27             [1, 256, 28, 28]          590,080
# │    └─ReLU: 2-28                        [1, 256, 28, 28]          --
# ├─BatchNorm2d: 1-18                      [1, 256, 28, 28]          512
# ├─MaxUnpool2d: 1-19                      [1, 256, 57, 57]          --
# ├─Sequential: 1-20                       [1, 128, 61, 61]          --
# │    └─ConvTranspose2d: 2-29             [1, 128, 59, 59]          295,040
# │    └─ReLU: 2-30                        [1, 128, 59, 59]          --
# │    └─ConvTranspose2d: 2-31             [1, 128, 61, 61]          147,584
# │    └─ReLU: 2-32                        [1, 128, 61, 61]          --
# ├─BatchNorm2d: 1-21                      [1, 128, 61, 61]          256
# ├─MaxUnpool2d: 1-22                      [1, 128, 122, 122]        --
# ├─Sequential: 1-23                       [1, 64, 126, 126]         --
# │    └─ConvTranspose2d: 2-33             [1, 64, 124, 124]         73,792
# │    └─ReLU: 2-34                        [1, 64, 124, 124]         --
# │    └─ConvTranspose2d: 2-35             [1, 64, 126, 126]         36,928
# │    └─ReLU: 2-36                        [1, 64, 126, 126]         --
# ├─BatchNorm2d: 1-24                      [1, 64, 126, 126]         128
# ├─MaxUnpool2d: 1-25                      [1, 64, 252, 252]         --
# ├─Sequential: 1-26                       [1, 5, 256, 256]          --
# │    └─ConvTranspose2d: 2-37             [1, 5, 254, 254]          2,885
# │    └─ReLU: 2-38                        [1, 5, 254, 254]          --
# │    └─ConvTranspose2d: 2-39             [1, 5, 256, 256]          230
# │    └─ReLU: 2-40                        [1, 5, 256, 256]          --
# ├─Softmax: 1-27                          [1, 5, 256, 256]          --
# ==========================================================================================
# Total params: 28,252,395
# Trainable params: 28,252,395
# Non-trainable params: 0
# Total mult-adds (G): 17.54
# ==========================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 220.26
# Params size (MB): 113.01
# Estimated Total Size (MB): 334.05
# ==========================================================================================

# %%
print('Pre Training: ')
model.eval()
model.to('cpu')
for i in idx:
    img, label = data.__getitem__(i)
    visualize_predictions(model, img)
# Out:
# Pre Training:

# %%
epochs = 50
batch_size = 8
lr = 1e-2
momentum=0.9
loss_fn = nn.CrossEntropyLoss()

# %%
model = model.to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum)

train_size = len(data)
trainloader = DataLoader(data, batch_size=batch_size, shuffle=True, num_workers=2)

total_train_loss_hist = []
avg_train_loss_hist = []

model.train()

for epoch in range(epochs):
    print(f'Epoch {epoch+1}/{epochs}')
    
    total_train_loss=0
    
    #Training Loop
    for batch, (x,y) in enumerate(trainloader):
        x, y = x.to(device), y.to(device)
        x = (x - 127.5) / 255
        
        #Forward prop
        preds = model(x)
        loss = loss_fn(preds, y)
        total_train_loss += loss.item()
        
        #Backprop
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    avg_train_loss = total_train_loss / train_size
    print(f"Total Training Loss: {total_train_loss:<7f}")
    print(f"Avg Training Loss  : {avg_train_loss:<7f}")
    total_train_loss_hist.append(total_train_loss)
    avg_train_loss_hist.append(avg_train_loss)
# Out:
# Epoch 1/50
# Total Training Loss: 196.415792
# Avg Training Loss  : 0.196416
# Epoch 2/50
# Total Training Loss: 190.092574
# Avg Training Loss  : 0.190093
# Epoch 3/50
# Total Training Loss: 187.647651
# Avg Training Loss  : 0.187648
# Epoch 4/50
# Total Training Loss: 187.995117
# Avg Training Loss  : 0.187995
# Epoch 5/50
# Total Training Loss: 187.160176
# Avg Training Loss  : 0.187160
# Epoch 6/50
# Total Training Loss: 186.954622
# Avg Training Loss  : 0.186955
# Epoch 7/50
# Total Training Loss: 186.981480
# Avg Training Loss  : 0.186981
# Epoch 8/50
# Total Training Loss: 186.633658
# Avg Training Loss  : 0.186634
# Epoch 9/50
# Total Training Loss: 186.962189
# Avg Training Loss  : 0.186962
# Epoch 10/50
# Total Training Loss: 187.047469
# Avg Training Loss  : 0.187047
# Epoch 11/50
# Total Training Loss: 186.555936
# Avg Training Loss  : 0.186556
# Epoch 12/50
# Total Training Loss: 186.247396
# Avg Training Loss  : 0.186247
# Epoch 13/50
# Total Training Loss: 186.155210
# Avg Training Loss  : 0.186155
# Epoch 14/50
# Total Training Loss: 185.756092
# Avg Training Loss  : 0.185756
# Epoch 15/50
# Total Training Loss: 186.108663
# Avg Training Loss  : 0.186109
# Epoch 16/50
# Total Training Loss: 185.848558
# Avg Training Loss  : 0.185849
# Epoch 17/50
# Total Training Loss: 185.429708
# Avg Training Loss  : 0.185430
# Epoch 18/50
# Total Training Loss: 184.777734
# Avg Training Loss  : 0.184778
# Epoch 19/50
# Total Training Loss: 184.037594
# Avg Training Loss  : 0.184038
# Epoch 20/50
# Total Training Loss: 184.032321
# Avg Training Loss  : 0.184032
# Epoch 21/50
# Total Training Loss: 183.798261
# Avg Training Loss  : 0.183798
# Epoch 22/50
# Total Training Loss: 183.556290
# Avg Training Loss  : 0.183556
# Epoch 23/50
# Total Training Loss: 183.227531
# Avg Training Loss  : 0.183228
# Epoch 24/50
# Total Training Loss: 182.462776
# Avg Training Loss  : 0.182463
# Epoch 25/50
# Total Training Loss: 182.010352
# Avg Training Loss  : 0.182010
# Epoch 26/50
# Total Training Loss: 181.981426
# Avg Training Loss  : 0.181981
# Epoch 27/50
# Total Training Loss: 180.840356
# Avg Training Loss  : 0.180840
# Epoch 28/50
# Total Training Loss: 179.587371
# Avg Training Loss  : 0.179587
# Epoch 29/50
# Total Training Loss: 179.636968
# Avg Training Loss  : 0.179637
# Epoch 30/50
# Total Training Loss: 177.874904
# Avg Training Loss  : 0.177875
# Epoch 31/50
# Total Training Loss: 176.731862
# Avg Training Loss  : 0.176732
# Epoch 32/50
# Total Training Loss: 176.624257
# Avg Training Loss  : 0.176624
# Epoch 33/50
# Total Training Loss: 174.693379
# Avg Training Loss  : 0.174693
# Epoch 34/50
# Total Training Loss: 174.885476
# Avg Training Loss  : 0.174885
# Epoch 35/50
# Total Training Loss: 172.422538
# Avg Training Loss  : 0.172423
# Epoch 36/50
# Total Training Loss: 172.489584
# Avg Training Loss  : 0.172490
# Epoch 37/50
# Total Training Loss: 170.754311
# Avg Training Loss  : 0.170754
# Epoch 38/50
# Total Training Loss: 169.490988
# Avg Training Loss  : 0.169491
# Epoch 39/50
# Total Training Loss: 167.596683
# Avg Training Loss  : 0.167597
# Epoch 40/50
# Total Training Loss: 166.209608
# Avg Training Loss  : 0.166210
# Epoch 41/50
# Total Training Loss: 165.547074
# Avg Training Loss  : 0.165547
# Epoch 42/50
# Total Training Loss: 167.531829
# Avg Training Loss  : 0.167532
# Epoch 43/50
# Total Training Loss: 164.738736
# Avg Training Loss  : 0.164739
# Epoch 44/50
# Total Training Loss: 162.874227
# Avg Training Loss  : 0.162874
# Epoch 45/50
# Total Training Loss: 162.429299
# Avg Training Loss  : 0.162429
# Epoch 46/50
# Total Training Loss: 161.669663
# Avg Training Loss  : 0.161670
# Epoch 47/50
# Total Training Loss: 159.168020
# Avg Training Loss  : 0.159168
# Epoch 48/50
# Total Training Loss: 158.308344
# Avg Training Loss  : 0.158308
# Epoch 49/50
# Total Training Loss: 155.302309
# Avg Training Loss  : 0.155302
# Epoch 50/50
# Total Training Loss: 154.862348
# Avg Training Loss  : 0.154862

# %%
plt.ylabel('Avg Loss per epoch')
plt.xlabel('Epochs')
plt.plot(avg_train_loss_hist, label='Cross Entropy Loss')
plt.legend()
plt.show()

# %%
print('Post Training: ')
model.to('cpu')
model.eval()
for i in (idx):
    img, label = data.__getitem__(i)
    visualize_predictions(model, img)
# Out:
# Post Training:
