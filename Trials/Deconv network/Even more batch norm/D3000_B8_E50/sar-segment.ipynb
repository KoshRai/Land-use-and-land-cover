# %%
# !pip install torchinfo
# !pip install torchmetrics
# !pip install torchsummary

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# from google.colab.patches import cv2_imshow as imshow

# %%
# !unzip "/content/gdrive/MyDrive/Dataset.zip" -d "/content/gdrive/MyDrive/SAR_Dataset"

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import os
import torchinfo

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
class SARData(Dataset):
    def __init__(self):
        
        self.xtrain_path = '/kaggle/input/sar8bit/Dataset/img_dir'
        self.ytrain_path = '/kaggle/input/sar8bit/Dataset/ann_dir_8bit'
        self.xtrain_imgs = np.array(os.listdir(self.xtrain_path))[:3000]
        self.ytrain_imgs = np.array(os.listdir(self.ytrain_path))[:3000]
        self.num_classes = 5
        self.height, self.width = 256,256

    def process_label(self, label):
        r = []
        for i in range(self.num_classes):
            mask = label == i+1
            mask = mask.float()
            r.append(mask)
        return torch.stack(r)
    
    def __len__(self):
        return len(self.ytrain_imgs)
    
    def __getitem__(self, idx):        
        xtrain = cv.imread(f"{self.xtrain_path}/{self.xtrain_imgs[idx]}")
        xtrain = cv.cvtColor(xtrain, cv.COLOR_BGR2RGB)
        xtrain = torch.tensor(xtrain).permute(2,0,1) #HWC -> CHW
        
        ytrain = cv.imread(f"{self.ytrain_path}/{self.ytrain_imgs[idx]}", cv.IMREAD_GRAYSCALE)
        ytrain = torch.tensor(ytrain)
        processed_ytrain = self.process_label(ytrain)
        
        
        return xtrain, processed_ytrain

# %%
def visualize_sample(img, label):
    fig, ax = plt.subplots(1, 6, figsize=(20,20)) 
    for i, subplot_ax in zip(range(data.num_classes + 1), ax.flatten()):
        if i == 0: 
            subplot_ax.imshow(img.permute(1,2,0))
            subplot_ax.set_title(f'Training Sample')
        else:
            subplot_ax.imshow(label[i-1], cmap='gray', vmin=0, vmax=1)
            subplot_ax.set_title(f'Label {i}')

def visualize_predictions(model, img):
    inp = (img - 127.5) / 255
    inp = torch.unsqueeze(inp, dim=0)
    pred = model(inp)
    visualize_sample(img, pred.squeeze().detach().numpy())

# %%
data = SARData()
idx = (torch.randint(0, 3000, (5,)))

for i in idx:
    img, label = data.__getitem__(i)
    visualize_sample(img, label)

# %%
def double_conv(in_channels, out_channels):
    conv = nn.Sequential(
        nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU()
    )
    return conv

def double_Tconv(in_channels, out_channels):
    Tconv = nn.Sequential(
        nn.ConvTranspose2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.ConvTranspose2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU()
    )
    return Tconv

class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2, return_indices=True)
        self.max_unpool = nn.MaxUnpool2d(kernel_size=2, stride=2)
        self.conv1 = double_conv(3, 64)
        self.conv2 = double_conv(64, 128)
        self.conv3 = double_conv(128, 256)
        self.conv4 = double_conv(256, 512)
        self.conv5 = double_conv(512, 1024)
        self.Tconv5 = double_Tconv(1024, 512)
        self.Tconv4 = double_Tconv(512, 256)
        self.Tconv3 = double_Tconv(256, 128)
        self.Tconv2 = double_Tconv(128, 64)
        self.Tconv1 = double_Tconv(64, 5)
        self.bn1 = nn.BatchNorm2d(64)
        self.bn2 = nn.BatchNorm2d(128)
        self.bn3 = nn.BatchNorm2d(256)
        self.bn4 = nn.BatchNorm2d(512)
        self.bn4u = nn.BatchNorm2d(512)
        self.bn3u = nn.BatchNorm2d(256)
        self.bn2u = nn.BatchNorm2d(128)
        self.bn1u = nn.BatchNorm2d(64)
        self.softmax = nn.Softmax(dim=1)
    
    def forward(self, x):
        c1 = self.conv1(x)
        c1 = self.bn1(c1)
        x1, i1 = self.max_pool(c1)

        c2 = self.conv2(x1)
        c2 - self.bn2(c2)
        x2, i2 = self.max_pool(c2)
        
        c3 = self.conv3(x2)
        c3 = self.bn3(c3)
        x3, i3 = self.max_pool(c3)

        c4 = self.conv4(x3)
        c4 = self.bn4(c4)
        x4, i4 = self.max_pool(c4)
        
        i = self.conv5(x4)
        
        t4 = self.Tconv5(i)
        
        t4 = self.bn4u(t4)
        z4 = self.max_unpool(t4, i4, output_size=c4.size())
        t3 = self.Tconv4(z4)
        
        t3 = self.bn3u(t3)
        z3 = self.max_unpool(t3, i3, output_size=c3.size())
        t2 = self.Tconv3(z3)
        
        t2 = self.bn2u(t2)
        z2 = self.max_unpool(t2, i2, output_size=c2.size())
        t1 = self.Tconv2(z2)
        
        t1 = self.bn1u(t1)
        z1 = self.max_unpool(t1, i1, output_size=c1.size())
        out = self.Tconv1(z1)
        
        return self.softmax(out)

# %%
model = Network()
# model.eval()
torchinfo.summary(model, (1,3,256,256))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Network                                  [1, 5, 256, 256]          --
# ├─Sequential: 1-1                        [1, 64, 252, 252]         --
# │    └─Conv2d: 2-1                       [1, 64, 254, 254]         1,792
# │    └─ReLU: 2-2                         [1, 64, 254, 254]         --
# │    └─Conv2d: 2-3                       [1, 64, 252, 252]         36,928
# │    └─ReLU: 2-4                         [1, 64, 252, 252]         --
# ├─BatchNorm2d: 1-2                       [1, 64, 252, 252]         128
# ├─MaxPool2d: 1-3                         [1, 64, 126, 126]         --
# ├─Sequential: 1-4                        [1, 128, 122, 122]        --
# │    └─Conv2d: 2-5                       [1, 128, 124, 124]        73,856
# │    └─ReLU: 2-6                         [1, 128, 124, 124]        --
# │    └─Conv2d: 2-7                       [1, 128, 122, 122]        147,584
# │    └─ReLU: 2-8                         [1, 128, 122, 122]        --
# ├─BatchNorm2d: 1-5                       [1, 128, 122, 122]        256
# ├─MaxPool2d: 1-6                         [1, 128, 61, 61]          --
# ├─Sequential: 1-7                        [1, 256, 57, 57]          --
# │    └─Conv2d: 2-9                       [1, 256, 59, 59]          295,168
# │    └─ReLU: 2-10                        [1, 256, 59, 59]          --
# │    └─Conv2d: 2-11                      [1, 256, 57, 57]          590,080
# │    └─ReLU: 2-12                        [1, 256, 57, 57]          --
# ├─BatchNorm2d: 1-8                       [1, 256, 57, 57]          512
# ├─MaxPool2d: 1-9                         [1, 256, 28, 28]          --
# ├─Sequential: 1-10                       [1, 512, 24, 24]          --
# │    └─Conv2d: 2-13                      [1, 512, 26, 26]          1,180,160
# │    └─ReLU: 2-14                        [1, 512, 26, 26]          --
# │    └─Conv2d: 2-15                      [1, 512, 24, 24]          2,359,808
# │    └─ReLU: 2-16                        [1, 512, 24, 24]          --
# ├─BatchNorm2d: 1-11                      [1, 512, 24, 24]          1,024
# ├─MaxPool2d: 1-12                        [1, 512, 12, 12]          --
# ├─Sequential: 1-13                       [1, 1024, 8, 8]           --
# │    └─Conv2d: 2-17                      [1, 1024, 10, 10]         4,719,616
# │    └─ReLU: 2-18                        [1, 1024, 10, 10]         --
# │    └─Conv2d: 2-19                      [1, 1024, 8, 8]           9,438,208
# │    └─ReLU: 2-20                        [1, 1024, 8, 8]           --
# ├─Sequential: 1-14                       [1, 512, 12, 12]          --
# │    └─ConvTranspose2d: 2-21             [1, 512, 10, 10]          4,719,104
# │    └─ReLU: 2-22                        [1, 512, 10, 10]          --
# │    └─ConvTranspose2d: 2-23             [1, 512, 12, 12]          2,359,808
# │    └─ReLU: 2-24                        [1, 512, 12, 12]          --
# ├─BatchNorm2d: 1-15                      [1, 512, 12, 12]          1,024
# ├─MaxUnpool2d: 1-16                      [1, 512, 24, 24]          --
# ├─Sequential: 1-17                       [1, 256, 28, 28]          --
# │    └─ConvTranspose2d: 2-25             [1, 256, 26, 26]          1,179,904
# │    └─ReLU: 2-26                        [1, 256, 26, 26]          --
# │    └─ConvTranspose2d: 2-27             [1, 256, 28, 28]          590,080
# │    └─ReLU: 2-28                        [1, 256, 28, 28]          --
# ├─BatchNorm2d: 1-18                      [1, 256, 28, 28]          512
# ├─MaxUnpool2d: 1-19                      [1, 256, 57, 57]          --
# ├─Sequential: 1-20                       [1, 128, 61, 61]          --
# │    └─ConvTranspose2d: 2-29             [1, 128, 59, 59]          295,040
# │    └─ReLU: 2-30                        [1, 128, 59, 59]          --
# │    └─ConvTranspose2d: 2-31             [1, 128, 61, 61]          147,584
# │    └─ReLU: 2-32                        [1, 128, 61, 61]          --
# ├─BatchNorm2d: 1-21                      [1, 128, 61, 61]          256
# ├─MaxUnpool2d: 1-22                      [1, 128, 122, 122]        --
# ├─Sequential: 1-23                       [1, 64, 126, 126]         --
# │    └─ConvTranspose2d: 2-33             [1, 64, 124, 124]         73,792
# │    └─ReLU: 2-34                        [1, 64, 124, 124]         --
# │    └─ConvTranspose2d: 2-35             [1, 64, 126, 126]         36,928
# │    └─ReLU: 2-36                        [1, 64, 126, 126]         --
# ├─BatchNorm2d: 1-24                      [1, 64, 126, 126]         128
# ├─MaxUnpool2d: 1-25                      [1, 64, 252, 252]         --
# ├─Sequential: 1-26                       [1, 5, 256, 256]          --
# │    └─ConvTranspose2d: 2-37             [1, 5, 254, 254]          2,885
# │    └─ReLU: 2-38                        [1, 5, 254, 254]          --
# │    └─ConvTranspose2d: 2-39             [1, 5, 256, 256]          230
# │    └─ReLU: 2-40                        [1, 5, 256, 256]          --
# ├─Softmax: 1-27                          [1, 5, 256, 256]          --
# ==========================================================================================
# Total params: 28,252,395
# Trainable params: 28,252,395
# Non-trainable params: 0
# Total mult-adds (G): 17.54
# ==========================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 220.26
# Params size (MB): 113.01
# Estimated Total Size (MB): 334.05
# ==========================================================================================

# %%
print('Pre Training: ')
model.eval()
model.to('cpu')
for i in idx:
    img, label = data.__getitem__(i)
    visualize_predictions(model, img)
# Out:
# Pre Training:

# %%
epochs = 50
batch_size = 8
lr = 1e-2
loss_fn = nn.CrossEntropyLoss()

# %%
model = model.to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

train_size = len(data)
trainloader = DataLoader(data, batch_size=batch_size, shuffle=True)
train_loss_hist = []

model.train()

for epoch in range(epochs):
    print(f'Epoch {epoch+1}/{epochs}')
    
    total_train_loss=0
    val_loss=0
    
    #Training Loop
    for batch, (x,y) in enumerate(trainloader):
        x, y = x.to(device), y.to(device)
        x = (x - 127.5) / 255
        
        #Forward prop
        preds = model(x)
        loss = loss_fn(preds, y)
        total_train_loss += loss.item()
        
        #Backprop
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    avg_train_loss = total_train_loss / train_size
    print(f"Total Training Loss: {total_train_loss:<7f}")
    print(f"Avg Training Loss  : {avg_train_loss:<7f}")
    train_loss_hist.append(total_train_loss)
# Out:
# Epoch 1/50
# Total Training Loss: 595.639586
# Avg Training Loss  : 0.198547
# Epoch 2/50
# Total Training Loss: 580.914696
# Avg Training Loss  : 0.193638
# Epoch 3/50
# Total Training Loss: 573.107429
# Avg Training Loss  : 0.191036
# Epoch 4/50
# Total Training Loss: 568.252632
# Avg Training Loss  : 0.189418
# Epoch 5/50
# Total Training Loss: 564.123183
# Avg Training Loss  : 0.188041
# Epoch 6/50
# Total Training Loss: 560.517917
# Avg Training Loss  : 0.186839
# Epoch 7/50
# Total Training Loss: 558.156614
# Avg Training Loss  : 0.186052
# Epoch 8/50
# Total Training Loss: 556.584914
# Avg Training Loss  : 0.185528
# Epoch 9/50
# Total Training Loss: 555.930259
# Avg Training Loss  : 0.185310
# Epoch 10/50
# Total Training Loss: 554.203722
# Avg Training Loss  : 0.184735
# Epoch 11/50
# Total Training Loss: 553.457018
# Avg Training Loss  : 0.184486
# Epoch 12/50
# Total Training Loss: 553.192681
# Avg Training Loss  : 0.184398
# Epoch 13/50
# Total Training Loss: 553.472925
# Avg Training Loss  : 0.184491
# Epoch 14/50
# Total Training Loss: 552.059930
# Avg Training Loss  : 0.184020
# Epoch 15/50
# Total Training Loss: 552.296474
# Avg Training Loss  : 0.184099
# Epoch 16/50
# Total Training Loss: 551.278554
# Avg Training Loss  : 0.183760
# Epoch 17/50
# Total Training Loss: 551.275540
# Avg Training Loss  : 0.183759
# Epoch 18/50
# Total Training Loss: 550.491099
# Avg Training Loss  : 0.183497
# Epoch 19/50
# Total Training Loss: 551.165443
# Avg Training Loss  : 0.183722
# Epoch 20/50
# Total Training Loss: 549.993089
# Avg Training Loss  : 0.183331
# Epoch 21/50
# Total Training Loss: 548.843910
# Avg Training Loss  : 0.182948
# Epoch 22/50
# Total Training Loss: 548.673742
# Avg Training Loss  : 0.182891
# Epoch 23/50
# Total Training Loss: 547.173301
# Avg Training Loss  : 0.182391
# Epoch 24/50
# Total Training Loss: 547.031875
# Avg Training Loss  : 0.182344
# Epoch 25/50
# Total Training Loss: 546.299384
# Avg Training Loss  : 0.182100
# Epoch 26/50
# Total Training Loss: 543.891692
# Avg Training Loss  : 0.181297
# Epoch 27/50
# Total Training Loss: 541.803184
# Avg Training Loss  : 0.180601
# Epoch 28/50
# Total Training Loss: 541.457936
# Avg Training Loss  : 0.180486
# Epoch 29/50
# Total Training Loss: 539.000354
# Avg Training Loss  : 0.179667
# Epoch 30/50
# Total Training Loss: 537.319327
# Avg Training Loss  : 0.179106
# Epoch 31/50
# Total Training Loss: 532.154211
# Avg Training Loss  : 0.177385
# Epoch 32/50
# Total Training Loss: 528.307940
# Avg Training Loss  : 0.176103
# Epoch 33/50
# Total Training Loss: 524.336564
# Avg Training Loss  : 0.174779
# Epoch 34/50
# Total Training Loss: 519.436215
# Avg Training Loss  : 0.173145
# Epoch 35/50
# Total Training Loss: 511.726810
# Avg Training Loss  : 0.170576
# Epoch 36/50
# Total Training Loss: 504.808263
# Avg Training Loss  : 0.168269
# Epoch 37/50
# Total Training Loss: 499.483740
# Avg Training Loss  : 0.166495
# Epoch 38/50
# Total Training Loss: 494.176000
# Avg Training Loss  : 0.164725
# Epoch 39/50
# Total Training Loss: 489.392009
# Avg Training Loss  : 0.163131
# Epoch 40/50
# Total Training Loss: 485.252048
# Avg Training Loss  : 0.161751
# Epoch 41/50
# Total Training Loss: 481.610635
# Avg Training Loss  : 0.160537
# Epoch 42/50
# Total Training Loss: 479.520458
# Avg Training Loss  : 0.159840
# Epoch 43/50
# Total Training Loss: 476.925400
# Avg Training Loss  : 0.158975
# Epoch 44/50
# Total Training Loss: 476.830201
# Avg Training Loss  : 0.158943
# Epoch 45/50
# Total Training Loss: 475.596735
# Avg Training Loss  : 0.158532
# Epoch 46/50
# Total Training Loss: 474.158632
# Avg Training Loss  : 0.158053
# Epoch 47/50
# Total Training Loss: 473.238985
# Avg Training Loss  : 0.157746
# Epoch 48/50
# Total Training Loss: 471.765984
# Avg Training Loss  : 0.157255
# Epoch 49/50
# Total Training Loss: 470.987412
# Avg Training Loss  : 0.156996
# Epoch 50/50
# Total Training Loss: 470.751487
# Avg Training Loss  : 0.156917

# %%
plt.ylabel('Total Loss per epoch')
plt.xlabel('Epochs')
plt.plot(train_loss_hist, label='Cross Entropy Loss')
plt.legend()
plt.show()

# %%
print('Post Training: ')
model.to('cpu')
model.eval()
for i in (idx):
    img, label = data.__getitem__(i)
    visualize_predictions(model, img)
# Out:
# Post Training:
