# %%
# !pip install torchinfo
# !pip install torchmetrics
# !pip install torchsummary

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# from google.colab.patches import cv2_imshow as imshow

# %%
# !unzip "/content/gdrive/MyDrive/Dataset.zip" -d "/content/gdrive/MyDrive/SAR_Dataset"

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import os
import torchinfo

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
class SARData(Dataset):
    def __init__(self):
        
        self.xtrain_path = '/kaggle/input/sar8bit/Dataset/img_dir'
        self.ytrain_path = '/kaggle/input/sar8bit/Dataset/ann_dir_8bit'
        self.xtrain_imgs = np.array(os.listdir(self.xtrain_path))[:3000]
        self.ytrain_imgs = np.array(os.listdir(self.ytrain_path))[:3000]
        self.num_classes = 5
        self.height, self.width = 256,256

    def process_label(self, label):
        r = []
        for i in range(self.num_classes):
            mask = label == i+1
            mask = mask.float()
            r.append(mask)
        return torch.stack(r)
    
    def __len__(self):
        return len(self.ytrain_imgs)
    
    def __getitem__(self, idx):        
        xtrain = cv.imread(f"{self.xtrain_path}/{self.xtrain_imgs[idx]}")
        xtrain = cv.cvtColor(xtrain, cv.COLOR_BGR2RGB)
        xtrain = torch.tensor(xtrain).permute(2,0,1) #HWC -> CHW
        
        ytrain = cv.imread(f"{self.ytrain_path}/{self.ytrain_imgs[idx]}", cv.IMREAD_GRAYSCALE)
        ytrain = torch.tensor(ytrain)
        processed_ytrain = self.process_label(ytrain)
        
        
        return xtrain, processed_ytrain

# %%
def visualize_sample(img, label):
    fig, ax = plt.subplots(1, 6, figsize=(20,20)) 
    for i, subplot_ax in zip(range(data.num_classes + 1), ax.flatten()):
        if i == 0: 
            subplot_ax.imshow(img.permute(1,2,0))
            subplot_ax.set_title(f'Training Sample')
        else:
            subplot_ax.imshow(label[i-1], cmap='gray', vmin=0, vmax=1)
            subplot_ax.set_title(f'Label {i}')

def visualize_predictions(model, img):
    inp = (img - 127.5) / 255
    inp = torch.unsqueeze(inp, dim=0)
    pred = model(inp)
    visualize_sample(img, pred.squeeze().detach().numpy())

# %%
data = SARData()
idx = (torch.randint(0, 3000, (5,)))

for i in idx:
    img, label = data.__getitem__(i)
    visualize_sample(img, label)

# %%
def double_conv(in_channels, out_channels):
    conv = nn.Sequential(
        nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU()
    )
    return conv

def double_Tconv(in_channels, out_channels):
    Tconv = nn.Sequential(
        nn.ConvTranspose2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.ConvTranspose2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU()
    )
    return Tconv

class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2, return_indices=True)
        self.max_unpool = nn.MaxUnpool2d(kernel_size=2, stride=2)
        self.conv1 = double_conv(3, 64)
        self.conv2 = double_conv(64, 128)
        self.conv3 = double_conv(128, 256)
        self.conv4 = double_conv(256, 512)
        self.conv5 = double_conv(512, 1024)
        self.Tconv5 = double_Tconv(1024, 512)
        self.Tconv4 = double_Tconv(512, 256)
        self.Tconv3 = double_Tconv(256, 128)
        self.Tconv2 = double_Tconv(128, 64)
        self.Tconv1 = double_Tconv(64, 5)
        self.bn1 = nn.BatchNorm2d(64)
        self.bn2 = nn.BatchNorm2d(128)
        self.bn3 = nn.BatchNorm2d(256)
        self.bn4 = nn.BatchNorm2d(512)
        self.softmax = nn.Softmax(dim=1)
    
    def forward(self, x):
        c1 = self.conv1(x)
        c1 = self.bn1(c1)
        x1, i1 = self.max_pool(c1)

        c2 = self.conv2(x1)
        c2 - self.bn2(c2)
        x2, i2 = self.max_pool(c2)
        
        c3 = self.conv3(x2)
        c3 = self.bn3(c3)
        x3, i3 = self.max_pool(c3)

        c4 = self.conv4(x3)
        c4 = self.bn4(c4)
        x4, i4 = self.max_pool(c4)
        
        i = self.conv5(x4)
        
        t4 = self.Tconv5(i)
        
        z4 = self.max_unpool(t4, i4, output_size=c4.size())
        t3 = self.Tconv4(z4)
        
        z3 = self.max_unpool(t3, i3, output_size=c3.size())
        t2 = self.Tconv3(z3)
        
        z2 = self.max_unpool(t2, i2, output_size=c2.size())
        t1 = self.Tconv2(z2)
        
        z1 = self.max_unpool(t1, i1, output_size=c1.size())
        out = self.Tconv1(z1)
        
        return self.softmax(out)

# %%
model = Network()
# model.eval()
torchinfo.summary(model, (1,3,256,256))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Network                                  [1, 5, 256, 256]          --
# ├─Sequential: 1-1                        [1, 64, 252, 252]         --
# │    └─Conv2d: 2-1                       [1, 64, 254, 254]         1,792
# │    └─ReLU: 2-2                         [1, 64, 254, 254]         --
# │    └─Conv2d: 2-3                       [1, 64, 252, 252]         36,928
# │    └─ReLU: 2-4                         [1, 64, 252, 252]         --
# ├─BatchNorm2d: 1-2                       [1, 64, 252, 252]         128
# ├─MaxPool2d: 1-3                         [1, 64, 126, 126]         --
# ├─Sequential: 1-4                        [1, 128, 122, 122]        --
# │    └─Conv2d: 2-5                       [1, 128, 124, 124]        73,856
# │    └─ReLU: 2-6                         [1, 128, 124, 124]        --
# │    └─Conv2d: 2-7                       [1, 128, 122, 122]        147,584
# │    └─ReLU: 2-8                         [1, 128, 122, 122]        --
# ├─BatchNorm2d: 1-5                       [1, 128, 122, 122]        256
# ├─MaxPool2d: 1-6                         [1, 128, 61, 61]          --
# ├─Sequential: 1-7                        [1, 256, 57, 57]          --
# │    └─Conv2d: 2-9                       [1, 256, 59, 59]          295,168
# │    └─ReLU: 2-10                        [1, 256, 59, 59]          --
# │    └─Conv2d: 2-11                      [1, 256, 57, 57]          590,080
# │    └─ReLU: 2-12                        [1, 256, 57, 57]          --
# ├─BatchNorm2d: 1-8                       [1, 256, 57, 57]          512
# ├─MaxPool2d: 1-9                         [1, 256, 28, 28]          --
# ├─Sequential: 1-10                       [1, 512, 24, 24]          --
# │    └─Conv2d: 2-13                      [1, 512, 26, 26]          1,180,160
# │    └─ReLU: 2-14                        [1, 512, 26, 26]          --
# │    └─Conv2d: 2-15                      [1, 512, 24, 24]          2,359,808
# │    └─ReLU: 2-16                        [1, 512, 24, 24]          --
# ├─BatchNorm2d: 1-11                      [1, 512, 24, 24]          1,024
# ├─MaxPool2d: 1-12                        [1, 512, 12, 12]          --
# ├─Sequential: 1-13                       [1, 1024, 8, 8]           --
# │    └─Conv2d: 2-17                      [1, 1024, 10, 10]         4,719,616
# │    └─ReLU: 2-18                        [1, 1024, 10, 10]         --
# │    └─Conv2d: 2-19                      [1, 1024, 8, 8]           9,438,208
# │    └─ReLU: 2-20                        [1, 1024, 8, 8]           --
# ├─Sequential: 1-14                       [1, 512, 12, 12]          --
# │    └─ConvTranspose2d: 2-21             [1, 512, 10, 10]          4,719,104
# │    └─ReLU: 2-22                        [1, 512, 10, 10]          --
# │    └─ConvTranspose2d: 2-23             [1, 512, 12, 12]          2,359,808
# │    └─ReLU: 2-24                        [1, 512, 12, 12]          --
# ├─MaxUnpool2d: 1-15                      [1, 512, 24, 24]          --
# ├─Sequential: 1-16                       [1, 256, 28, 28]          --
# │    └─ConvTranspose2d: 2-25             [1, 256, 26, 26]          1,179,904
# │    └─ReLU: 2-26                        [1, 256, 26, 26]          --
# │    └─ConvTranspose2d: 2-27             [1, 256, 28, 28]          590,080
# │    └─ReLU: 2-28                        [1, 256, 28, 28]          --
# ├─MaxUnpool2d: 1-17                      [1, 256, 57, 57]          --
# ├─Sequential: 1-18                       [1, 128, 61, 61]          --
# │    └─ConvTranspose2d: 2-29             [1, 128, 59, 59]          295,040
# │    └─ReLU: 2-30                        [1, 128, 59, 59]          --
# │    └─ConvTranspose2d: 2-31             [1, 128, 61, 61]          147,584
# │    └─ReLU: 2-32                        [1, 128, 61, 61]          --
# ├─MaxUnpool2d: 1-19                      [1, 128, 122, 122]        --
# ├─Sequential: 1-20                       [1, 64, 126, 126]         --
# │    └─ConvTranspose2d: 2-33             [1, 64, 124, 124]         73,792
# │    └─ReLU: 2-34                        [1, 64, 124, 124]         --
# │    └─ConvTranspose2d: 2-35             [1, 64, 126, 126]         36,928
# │    └─ReLU: 2-36                        [1, 64, 126, 126]         --
# ├─MaxUnpool2d: 1-21                      [1, 64, 252, 252]         --
# ├─Sequential: 1-22                       [1, 5, 256, 256]          --
# │    └─ConvTranspose2d: 2-37             [1, 5, 254, 254]          2,885
# │    └─ReLU: 2-38                        [1, 5, 254, 254]          --
# │    └─ConvTranspose2d: 2-39             [1, 5, 256, 256]          230
# │    └─ReLU: 2-40                        [1, 5, 256, 256]          --
# ├─Softmax: 1-23                          [1, 5, 256, 256]          --
# ==========================================================================================
# Total params: 28,250,475
# Trainable params: 28,250,475
# Non-trainable params: 0
# Total mult-adds (G): 17.54
# ==========================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 206.12
# Params size (MB): 113.00
# Estimated Total Size (MB): 319.91
# ==========================================================================================

# %%
print('Pre Training: ')
model.eval()
model.to('cpu')
for i in idx:
    img, label = data.__getitem__(i)
    visualize_predictions(model, img)
# Out:
# Pre Training:

# %%
epochs = 50
batch_size = 8
lr = 1e-2
loss_fn = nn.CrossEntropyLoss()

# %%
model.train()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

train_size = len(data)
trainloader = DataLoader(data, batch_size=batch_size, shuffle=True)
train_loss_hist = []

model = model.to(device)

for epoch in range(epochs):
    print(f'Epoch {epoch+1}/{epochs}')
    
    total_train_loss=0
    val_loss=0
    
    #Training Loop
    for batch, (x,y) in enumerate(trainloader):
        x, y = x.to(device), y.to(device)
        x = (x - 127.5) / 255
        
        #Forward prop
        preds = model(x)
        loss = loss_fn(preds, y)
        total_train_loss += loss.item()
        
        #Backprop
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    avg_train_loss = total_train_loss / train_size
    print(f"Total Training Loss: {total_train_loss:<7f}")
    print(f"Avg Training Loss  : {avg_train_loss:<7f}")
    train_loss_hist.append(total_train_loss)
# Out:
# Epoch 1/50
# Total Training Loss 598.0053932666779
# Avg Training Loss 0.19933513108889261
# Epoch 2/50
# Total Training Loss 589.4810810089111
# Avg Training Loss 0.19649369366963704
# Epoch 3/50
# Total Training Loss 576.9701336622238
# Avg Training Loss 0.19232337788740794
# Epoch 4/50
# Total Training Loss 566.7709854841232
# Avg Training Loss 0.18892366182804107
# Epoch 5/50
# Total Training Loss 561.732635140419
# Avg Training Loss 0.187244211713473
# Epoch 6/50
# Total Training Loss 559.4690598249435
# Avg Training Loss 0.18648968660831453
# Epoch 7/50
# Total Training Loss 558.3243895769119
# Avg Training Loss 0.18610812985897066
# Epoch 8/50
# Total Training Loss 557.7112476825714
# Avg Training Loss 0.1859037492275238
# Epoch 9/50
# Total Training Loss 557.341296672821
# Avg Training Loss 0.18578043222427368
# Epoch 10/50
# Total Training Loss 557.1694231033325
# Avg Training Loss 0.18572314103444418
# Epoch 11/50
# Total Training Loss 556.9410549402237
# Avg Training Loss 0.1856470183134079
# Epoch 12/50
# Total Training Loss 556.8378425836563
# Avg Training Loss 0.1856126141945521
# Epoch 13/50
# Total Training Loss 556.7109980583191
# Avg Training Loss 0.18557033268610637
# Epoch 14/50
# Total Training Loss 556.6113990545273
# Avg Training Loss 0.18553713301817576
# Epoch 15/50
# Total Training Loss 556.6051017045975
# Avg Training Loss 0.1855350339015325
# Epoch 16/50
# Total Training Loss 556.4555556774139
# Avg Training Loss 0.18548518522580465
# Epoch 17/50
# Total Training Loss 556.3607375621796
# Avg Training Loss 0.1854535791873932
# Epoch 18/50
# Total Training Loss 556.5092188119888
# Avg Training Loss 0.18550307293732962
# Epoch 19/50
# Total Training Loss 556.4761673212051
# Avg Training Loss 0.18549205577373504
# Epoch 20/50
# Total Training Loss 556.350000500679
# Avg Training Loss 0.185450000166893
# Epoch 21/50
# Total Training Loss 556.4119718074799
# Avg Training Loss 0.18547065726915996
# Epoch 22/50
# Total Training Loss 556.4210875034332
# Avg Training Loss 0.18547369583447773
# Epoch 23/50
# Total Training Loss 556.4209160804749
# Avg Training Loss 0.18547363869349162
# Epoch 24/50
# Total Training Loss 556.3428425788879
# Avg Training Loss 0.18544761419296266
# Epoch 25/50
# Total Training Loss 556.3606405258179
# Avg Training Loss 0.1854535468419393
# Epoch 26/50
# Total Training Loss 556.441800236702
# Avg Training Loss 0.18548060007890066
# Epoch 27/50
# Total Training Loss 556.2699248790741
# Avg Training Loss 0.1854233082930247
# Epoch 28/50
# Total Training Loss 556.341735959053
# Avg Training Loss 0.18544724531968435
# Epoch 29/50
# Total Training Loss 556.3117731809616
# Avg Training Loss 0.18543725772698721
# Epoch 30/50
# Total Training Loss 556.3326468467712
# Avg Training Loss 0.1854442156155904
# Epoch 31/50
# Total Training Loss 556.3084615468979
# Avg Training Loss 0.18543615384896597
# Epoch 32/50
# Total Training Loss 556.1772162914276
# Avg Training Loss 0.18539240543047586
# Epoch 33/50
# Total Training Loss 556.3720436096191
# Avg Training Loss 0.18545734786987306
# Epoch 34/50
# Total Training Loss 556.2950594425201
# Avg Training Loss 0.18543168648084005
# Epoch 35/50
# Total Training Loss 556.2571156024933
# Avg Training Loss 0.18541903853416442
# Epoch 36/50
# Total Training Loss 556.3817516565323
# Avg Training Loss 0.18546058388551076
# Epoch 37/50
# Total Training Loss 556.2143495082855
# Avg Training Loss 0.18540478316942852
# Epoch 38/50
# Total Training Loss 556.2444925308228
# Avg Training Loss 0.18541483084360758
# Epoch 39/50
# Total Training Loss 556.1526584625244
# Avg Training Loss 0.18538421948750813
# Epoch 40/50
# Total Training Loss 556.2757054567337
# Avg Training Loss 0.18542523515224457
# Epoch 41/50
# Total Training Loss 556.1594885587692
# Avg Training Loss 0.1853864961862564
# Epoch 42/50
# Total Training Loss 556.2663229703903
# Avg Training Loss 0.1854221076567968
# Epoch 43/50
# Total Training Loss 556.2727432250977
# Avg Training Loss 0.18542424774169922
# Epoch 44/50
# Total Training Loss 556.2664231061935
# Avg Training Loss 0.18542214103539784
# Epoch 45/50
# Total Training Loss 556.0904500484467
# Avg Training Loss 0.18536348334948222
# Epoch 46/50
# Total Training Loss 556.1278357505798
# Avg Training Loss 0.18537594525019327
# Epoch 47/50
# Total Training Loss 556.266432762146
# Avg Training Loss 0.18542214425404865
# Epoch 48/50
# Total Training Loss 556.0813310146332
# Avg Training Loss 0.1853604436715444
# Epoch 49/50
# Total Training Loss 556.3006691932678
# Avg Training Loss 0.18543355639775594
# Epoch 50/50
# Total Training Loss 556.1736965179443
# Avg Training Loss 0.1853912321726481

# %%
plt.ylabel('Total Loss per epoch')
plt.xlabel('Epochs')
plt.plot(train_loss_hist, label='Cross Entropy Loss')
plt.legend()
plt.show()

# %%
print('Post Training: ')
model.to('cpu')
model.eval()
for i in (idx):
    img, label = data.__getitem__(i)
    visualize_predictions(model, img)
# Out:
# Post Training:
