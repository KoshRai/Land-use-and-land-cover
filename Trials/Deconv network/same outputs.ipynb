# %%
# !pip install torchinfo
# !pip install torchmetrics

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# from google.colab.patches import cv2_imshow as imshow

# %%
# !unzip "/content/gdrive/MyDrive/Dataset.zip" -d "/content/gdrive/MyDrive/SAR_Dataset"

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import os
import torchinfo

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
class SARData(Dataset):
    def __init__(self):
        
        self.xtrain_path = '/kaggle/input/sar8bit/Dataset/img_dir'
        self.ytrain_path = '/kaggle/input/sar8bit/Dataset/ann_dir_8bit'
        self.xtrain_imgs = np.array(os.listdir(self.xtrain_path))[:50]
        self.ytrain_imgs = np.array(os.listdir(self.ytrain_path))[:50]
        self.num_classes = 5
        self.height, self.width = 256,256

    def process_label(self, label):
        r = []
        for i in range(self.num_classes):
            mask = label == i+1
            mask = mask.float()
            r.append(mask)
        return torch.stack(r)
    
    def __len__(self):
        return len(self.ytrain_imgs)
    
    def __getitem__(self, idx):        
        xtrain = cv.imread(f"{self.xtrain_path}/{self.xtrain_imgs[idx]}")
        xtrain = cv.cvtColor(xtrain, cv.COLOR_BGR2RGB)
        xtrain = torch.tensor(xtrain).permute(2,0,1) #HWC -> CHW
        
        ytrain = cv.imread(f"{self.ytrain_path}/{self.ytrain_imgs[idx]}", cv.IMREAD_GRAYSCALE)
        ytrain = torch.tensor(ytrain)
        processed_ytrain = self.process_label(ytrain)
        
        
        return xtrain, processed_ytrain

# %%
def visualize_sample(img, label):
    fig, ax = plt.subplots(1, 6, figsize=(20,20)) 
    for i, subplot_ax in zip(range(data.num_classes + 1), ax.flatten()):
        if i == 0: 
            subplot_ax.imshow(img.permute(1,2,0))
            subplot_ax.set_title(f'Training Sample')
        else:
            subplot_ax.imshow(label[i-1], cmap='gray', vmin=0, vmax=1)
            subplot_ax.set_title(f'Label {i}')

def visualize_predictions(model, img):
    model = model.cpu()
    inp = img / 255
    inp = torch.unsqueeze(inp, dim=0)
    pred = model(inp)
    visualize_sample(img, pred.squeeze().detach().numpy())

# %%
data = SARData()
idx = (torch.randint(0, 50, (5,)))

for i in idx:
    img, label = data.__getitem__(i)
    visualize_sample(img, label)

# %%
def double_conv(in_channels, out_channels):
    conv = nn.Sequential(
        nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU()
    )
    return conv

def double_Tconv(in_channels, out_channels):
    Tconv = nn.Sequential(
        nn.ConvTranspose2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU(),
        nn.ConvTranspose2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, stride=1),
        nn.ReLU()
    )
    return Tconv

class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2, return_indices=True)
        self.max_unpool = nn.MaxUnpool2d(kernel_size=2, stride=2)
        self.conv1 = double_conv(3, 64)
        self.conv2 = double_conv(64, 128)
        self.conv3 = double_conv(128, 256)
        self.conv4 = double_conv(256, 512)
        self.conv5 = double_conv(512, 1024)
        self.Tconv5 = double_Tconv(1024, 512)
        self.Tconv4 = double_Tconv(512, 256)
        self.Tconv3 = double_Tconv(256, 128)
        self.Tconv2 = double_Tconv(128, 64)
        self.Tconv1 = double_Tconv(64, 5)
        self.softmax = nn.Softmax(dim=1)
    
    def forward(self, x):
        c1 = self.conv1(x)
        x1, i1 = self.max_pool(c1)

        c2 = self.conv2(x1)
        x2, i2 = self.max_pool(c2)
        
        c3 = self.conv3(x2)
        x3, i3 = self.max_pool(c3)

        c4 = self.conv4(x3)
        x4, i4 = self.max_pool(c4)

        i = self.conv5(x4)
        
        t4 = self.Tconv5(i)
        
        z4 = self.max_unpool(t4, i4, output_size=c4.size())
        t3 = self.Tconv4(z4)
        
        z3 = self.max_unpool(t3, i3, output_size=c3.size())
        t2 = self.Tconv3(z3)
        
        z2 = self.max_unpool(t2, i2, output_size=c2.size())
        t1 = self.Tconv2(z2)
        
        z1 = self.max_unpool(t1, i1, output_size=c1.size())
        out = self.Tconv1(z1)
        
        return self.softmax(out)

# %%
model = Network()
torchinfo.summary(model, (1, 3, 256, 256))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Network                                  [1, 5, 256, 256]          --
# ├─Sequential: 1-1                        [1, 64, 252, 252]         --
# │    └─Conv2d: 2-1                       [1, 64, 254, 254]         1,792
# │    └─ReLU: 2-2                         [1, 64, 254, 254]         --
# │    └─Conv2d: 2-3                       [1, 64, 252, 252]         36,928
# │    └─ReLU: 2-4                         [1, 64, 252, 252]         --
# ├─MaxPool2d: 1-2                         [1, 64, 126, 126]         --
# ├─Sequential: 1-3                        [1, 128, 122, 122]        --
# │    └─Conv2d: 2-5                       [1, 128, 124, 124]        73,856
# │    └─ReLU: 2-6                         [1, 128, 124, 124]        --
# │    └─Conv2d: 2-7                       [1, 128, 122, 122]        147,584
# │    └─ReLU: 2-8                         [1, 128, 122, 122]        --
# ├─MaxPool2d: 1-4                         [1, 128, 61, 61]          --
# ├─Sequential: 1-5                        [1, 256, 57, 57]          --
# │    └─Conv2d: 2-9                       [1, 256, 59, 59]          295,168
# │    └─ReLU: 2-10                        [1, 256, 59, 59]          --
# │    └─Conv2d: 2-11                      [1, 256, 57, 57]          590,080
# │    └─ReLU: 2-12                        [1, 256, 57, 57]          --
# ├─MaxPool2d: 1-6                         [1, 256, 28, 28]          --
# ├─Sequential: 1-7                        [1, 512, 24, 24]          --
# │    └─Conv2d: 2-13                      [1, 512, 26, 26]          1,180,160
# │    └─ReLU: 2-14                        [1, 512, 26, 26]          --
# │    └─Conv2d: 2-15                      [1, 512, 24, 24]          2,359,808
# │    └─ReLU: 2-16                        [1, 512, 24, 24]          --
# ├─MaxPool2d: 1-8                         [1, 512, 12, 12]          --
# ├─Sequential: 1-9                        [1, 1024, 8, 8]           --
# │    └─Conv2d: 2-17                      [1, 1024, 10, 10]         4,719,616
# │    └─ReLU: 2-18                        [1, 1024, 10, 10]         --
# │    └─Conv2d: 2-19                      [1, 1024, 8, 8]           9,438,208
# │    └─ReLU: 2-20                        [1, 1024, 8, 8]           --
# ├─Sequential: 1-10                       [1, 512, 12, 12]          --
# │    └─ConvTranspose2d: 2-21             [1, 512, 10, 10]          4,719,104
# │    └─ReLU: 2-22                        [1, 512, 10, 10]          --
# │    └─ConvTranspose2d: 2-23             [1, 512, 12, 12]          2,359,808
# │    └─ReLU: 2-24                        [1, 512, 12, 12]          --
# ├─MaxUnpool2d: 1-11                      [1, 512, 24, 24]          --
# ├─Sequential: 1-12                       [1, 256, 28, 28]          --
# │    └─ConvTranspose2d: 2-25             [1, 256, 26, 26]          1,179,904
# │    └─ReLU: 2-26                        [1, 256, 26, 26]          --
# │    └─ConvTranspose2d: 2-27             [1, 256, 28, 28]          590,080
# │    └─ReLU: 2-28                        [1, 256, 28, 28]          --
# ├─MaxUnpool2d: 1-13                      [1, 256, 57, 57]          --
# ├─Sequential: 1-14                       [1, 128, 61, 61]          --
# │    └─ConvTranspose2d: 2-29             [1, 128, 59, 59]          295,040
# │    └─ReLU: 2-30                        [1, 128, 59, 59]          --
# │    └─ConvTranspose2d: 2-31             [1, 128, 61, 61]          147,584
# │    └─ReLU: 2-32                        [1, 128, 61, 61]          --
# ├─MaxUnpool2d: 1-15                      [1, 128, 122, 122]        --
# ├─Sequential: 1-16                       [1, 64, 126, 126]         --
# │    └─ConvTranspose2d: 2-33             [1, 64, 124, 124]         73,792
# │    └─ReLU: 2-34                        [1, 64, 124, 124]         --
# │    └─ConvTranspose2d: 2-35             [1, 64, 126, 126]         36,928
# │    └─ReLU: 2-36                        [1, 64, 126, 126]         --
# ├─MaxUnpool2d: 1-17                      [1, 64, 252, 252]         --
# ├─Sequential: 1-18                       [1, 5, 256, 256]          --
# │    └─ConvTranspose2d: 2-37             [1, 5, 254, 254]          2,885
# │    └─ReLU: 2-38                        [1, 5, 254, 254]          --
# │    └─ConvTranspose2d: 2-39             [1, 5, 256, 256]          230
# │    └─ReLU: 2-40                        [1, 5, 256, 256]          --
# ├─Softmax: 1-19                          [1, 5, 256, 256]          --
# ==========================================================================================
# Total params: 28,248,555
# Trainable params: 28,248,555
# Non-trainable params: 0
# Total mult-adds (G): 17.54
# ==========================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 149.35
# Params size (MB): 112.99
# Estimated Total Size (MB): 263.14
# ==========================================================================================

# %%
print('Pre Training: ')
for i in idx:
    img, label = data.__getitem__(i)
    visualize_predictions(model, img)
# Out:
# Pre Training:

# %%
# train_data, val_data = torch.utils.data.random_split(data, [0.85, 0.15])
# print(len(train_data))
# print(len(val_data))

# %%
epochs = 200
batch_size = 16
lr = 1e-1
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
# train_size = len(train_data)
# val_size = len(val_data)
train_size = len(data)
trainloader = DataLoader(data, batch_size=batch_size, shuffle=True)
model = model.to(device)

train_loss_hist = []

for epoch in range(epochs):
    print(f'Epoch {epoch+1}/{epochs}')
    
    total_train_loss=0
    val_loss=0
    
    #Training Loop
    model.train()
    for batch, (x,y) in enumerate(trainloader):
        x, y = x.to(device), y.to(device)
        x = x / 255
        
        #Forward prop
        preds = model(x)
        loss = loss_fn(preds, y)
        total_train_loss += loss.item()
        
        #Backprop
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    avg_train_loss = total_train_loss / train_size
    print(f"Total Training Loss {total_train_loss}")
    print(f"Avg Training Loss {avg_train_loss}")
    train_loss_hist.append(total_train_loss)
# Out:
# Epoch 1/200
# Total Training Loss 6.220194101333618
# Avg Training Loss 0.12440388202667237
# Epoch 2/200
# Total Training Loss 6.38887882232666
# Avg Training Loss 0.1277775764465332
# Epoch 3/200
# Total Training Loss 6.416536927223206
# Avg Training Loss 0.1283307385444641
# Epoch 4/200
# Total Training Loss 6.43376362323761
# Avg Training Loss 0.1286752724647522
# Epoch 5/200
# Total Training Loss 6.190894365310669
# Avg Training Loss 0.12381788730621338
# Epoch 6/200
# Total Training Loss 6.427741646766663
# Avg Training Loss 0.12855483293533326
# Epoch 7/200
# Total Training Loss 6.284426331520081
# Avg Training Loss 0.12568852663040161
# Epoch 8/200
# Total Training Loss 6.433856725692749
# Avg Training Loss 0.12867713451385498
# Epoch 9/200
# Total Training Loss 6.3462547063827515
# Avg Training Loss 0.12692509412765504
# Epoch 10/200
# Total Training Loss 6.031198978424072
# Avg Training Loss 0.12062397956848145
# Epoch 11/200
# Total Training Loss 5.709654808044434
# Avg Training Loss 0.11419309616088867
# Epoch 12/200
# Total Training Loss 5.778608798980713
# Avg Training Loss 0.11557217597961426
# Epoch 13/200
# Total Training Loss 6.291499733924866
# Avg Training Loss 0.12582999467849731
# Epoch 14/200
# Total Training Loss 6.32125997543335
# Avg Training Loss 0.12642519950866699
# Epoch 15/200
# Total Training Loss 6.196696519851685
# Avg Training Loss 0.1239339303970337
# Epoch 16/200
# Total Training Loss 6.205406546592712
# Avg Training Loss 0.12410813093185424
# Epoch 17/200
# Total Training Loss 5.675083637237549
# Avg Training Loss 0.11350167274475098
# Epoch 18/200
# Total Training Loss 5.71440052986145
# Avg Training Loss 0.114288010597229
# Epoch 19/200
# Total Training Loss 6.313690543174744
# Avg Training Loss 0.12627381086349487
# Epoch 20/200
# Total Training Loss 6.02334988117218
# Avg Training Loss 0.12046699762344361
# Epoch 21/200
# Total Training Loss 5.996526479721069
# Avg Training Loss 0.11993052959442138
# Epoch 22/200
# Total Training Loss 6.427982926368713
# Avg Training Loss 0.12855965852737428
# Epoch 23/200
# Total Training Loss 6.313687205314636
# Avg Training Loss 0.12627374410629272
# Epoch 24/200
# Total Training Loss 6.031010031700134
# Avg Training Loss 0.12062020063400268
# Epoch 25/200
# Total Training Loss 5.996533989906311
# Avg Training Loss 0.11993067979812622
# Epoch 26/200
# Total Training Loss 5.872172474861145
# Avg Training Loss 0.11744344949722291
# Epoch 27/200
# Total Training Loss 5.688649773597717
# Avg Training Loss 0.11377299547195435
# Epoch 28/200
# Total Training Loss 6.110678315162659
# Avg Training Loss 0.12221356630325317
# Epoch 29/200
# Total Training Loss 6.087765336036682
# Avg Training Loss 0.12175530672073365
# Epoch 30/200
# Total Training Loss 6.213149428367615
# Avg Training Loss 0.1242629885673523
# Epoch 31/200
# Total Training Loss 6.433892488479614
# Avg Training Loss 0.1286778497695923
# Epoch 32/200
# Total Training Loss 6.070237994194031
# Avg Training Loss 0.12140475988388061
# Epoch 33/200
# Total Training Loss 6.015463948249817
# Avg Training Loss 0.12030927896499634
# Epoch 34/200
# Total Training Loss 6.36156165599823
# Avg Training Loss 0.1272312331199646
# Epoch 35/200
# Total Training Loss 6.346229314804077
# Avg Training Loss 0.12692458629608155
# Epoch 36/200
# Total Training Loss 6.360478758811951
# Avg Training Loss 0.12720957517623901
# Epoch 37/200
# Total Training Loss 6.313561797142029
# Avg Training Loss 0.12627123594284057
# Epoch 38/200
# Total Training Loss 5.7163310050964355
# Avg Training Loss 0.1143266201019287
# Epoch 39/200
# Total Training Loss 6.297434568405151
# Avg Training Loss 0.12594869136810302
# Epoch 40/200
# Total Training Loss 5.958895921707153
# Avg Training Loss 0.11917791843414306
# Epoch 41/200
# Total Training Loss 5.593957304954529
# Avg Training Loss 0.11187914609909058
# Epoch 42/200
# Total Training Loss 6.2864320278167725
# Avg Training Loss 0.12572864055633545
# Epoch 43/200
# Total Training Loss 5.99788510799408
# Avg Training Loss 0.1199577021598816
# Epoch 44/200
# Total Training Loss 6.433879971504211
# Avg Training Loss 0.12867759943008422
# Epoch 45/200
# Total Training Loss 6.0012054443359375
# Avg Training Loss 0.12002410888671874
# Epoch 46/200
# Total Training Loss 5.863330125808716
# Avg Training Loss 0.11726660251617432
# Epoch 47/200
# Total Training Loss 5.916233777999878
# Avg Training Loss 0.11832467555999755
# Epoch 48/200
# Total Training Loss 6.340362906455994
# Avg Training Loss 0.12680725812911986
# Epoch 49/200
# Total Training Loss 5.848020076751709
# Avg Training Loss 0.11696040153503418
# Epoch 50/200
# Total Training Loss 6.004502534866333
# Avg Training Loss 0.12009005069732666
# Epoch 51/200
# Total Training Loss 6.433902025222778
# Avg Training Loss 0.12867804050445555
# Epoch 52/200
# Total Training Loss 6.1435467004776
# Avg Training Loss 0.122870934009552
# Epoch 53/200
# Total Training Loss 6.195358157157898
# Avg Training Loss 0.12390716314315796
# Epoch 54/200
# Total Training Loss 6.113646864891052
# Avg Training Loss 0.12227293729782104
# Epoch 55/200
# Total Training Loss 6.251157283782959
# Avg Training Loss 0.12502314567565917
# Epoch 56/200
# Total Training Loss 6.429690957069397
# Avg Training Loss 0.12859381914138793
# Epoch 57/200
# Total Training Loss 6.029063105583191
# Avg Training Loss 0.12058126211166381
# Epoch 58/200
# Total Training Loss 5.9978872537612915
# Avg Training Loss 0.11995774507522583
# Epoch 59/200
# Total Training Loss 5.996541738510132
# Avg Training Loss 0.11993083477020264
# Epoch 60/200
# Total Training Loss 6.215939164161682
# Avg Training Loss 0.12431878328323365
# Epoch 61/200
# Total Training Loss 6.3207985162734985
# Avg Training Loss 0.12641597032546997
# Epoch 62/200
# Total Training Loss 6.4338061809539795
# Avg Training Loss 0.1286761236190796
# Epoch 63/200
# Total Training Loss 6.024715304374695
# Avg Training Loss 0.1204943060874939
# Epoch 64/200
# Total Training Loss 5.758240103721619
# Avg Training Loss 0.11516480207443237
# Epoch 65/200
# Total Training Loss 6.195336222648621
# Avg Training Loss 0.1239067244529724
# Epoch 66/200
# Total Training Loss 6.3521716594696045
# Avg Training Loss 0.1270434331893921
# Epoch 67/200
# Total Training Loss 6.030539870262146
# Avg Training Loss 0.12061079740524291
# Epoch 68/200
# Total Training Loss 5.996541619300842
# Avg Training Loss 0.11993083238601684
# Epoch 69/200
# Total Training Loss 6.241510391235352
# Avg Training Loss 0.12483020782470704
# Epoch 70/200
# Total Training Loss 5.849213004112244
# Avg Training Loss 0.11698426008224487
# Epoch 71/200
# Total Training Loss 5.659475088119507
# Avg Training Loss 0.11318950176239014
# Epoch 72/200
# Total Training Loss 5.848495006561279
# Avg Training Loss 0.11696990013122559
# Epoch 73/200
# Total Training Loss 6.253296256065369
# Avg Training Loss 0.12506592512130738
# Epoch 74/200
# Total Training Loss 6.243124485015869
# Avg Training Loss 0.12486248970031738
# Epoch 75/200
# Total Training Loss 5.9726879596710205
# Avg Training Loss 0.11945375919342041
# Epoch 76/200
# Total Training Loss 5.9403475522994995
# Avg Training Loss 0.11880695104598998
# Epoch 77/200
# Total Training Loss 5.996512174606323
# Avg Training Loss 0.11993024349212647
# Epoch 78/200
# Total Training Loss 6.308081030845642
# Avg Training Loss 0.12616162061691283
# Epoch 79/200
# Total Training Loss 6.352286219596863
# Avg Training Loss 0.12704572439193726
# Epoch 80/200
# Total Training Loss 6.1233989000320435
# Avg Training Loss 0.12246797800064087
# Epoch 81/200
# Total Training Loss 6.026936292648315
# Avg Training Loss 0.12053872585296631
# Epoch 82/200
# Total Training Loss 6.200696110725403
# Avg Training Loss 0.12401392221450806
# Epoch 83/200
# Total Training Loss 5.688604831695557
# Avg Training Loss 0.11377209663391114
# Epoch 84/200
# Total Training Loss 5.925533771514893
# Avg Training Loss 0.11851067543029785
# Epoch 85/200
# Total Training Loss 6.41640830039978
# Avg Training Loss 0.1283281660079956
# Epoch 86/200
# Total Training Loss 6.346320271492004
# Avg Training Loss 0.1269264054298401
# Epoch 87/200
# Total Training Loss 5.990597486495972
# Avg Training Loss 0.11981194972991943
# Epoch 88/200
# Total Training Loss 6.211145877838135
# Avg Training Loss 0.1242229175567627
# Epoch 89/200
# Total Training Loss 6.3616156578063965
# Avg Training Loss 0.12723231315612793
# Epoch 90/200
# Total Training Loss 6.433935046195984
# Avg Training Loss 0.12867870092391967
# Epoch 91/200
# Total Training Loss 5.996516704559326
# Avg Training Loss 0.11993033409118653
# Epoch 92/200
# Total Training Loss 6.338798522949219
# Avg Training Loss 0.12677597045898437
# Epoch 93/200
# Total Training Loss 5.7606799602508545
# Avg Training Loss 0.11521359920501709
# Epoch 94/200
# Total Training Loss 6.196721911430359
# Avg Training Loss 0.12393443822860718
# Epoch 95/200
# Total Training Loss 6.4339107275009155
# Avg Training Loss 0.12867821455001832
# Epoch 96/200
# Total Training Loss 5.925837159156799
# Avg Training Loss 0.11851674318313599
# Epoch 97/200
# Total Training Loss 5.9965208768844604
# Avg Training Loss 0.11993041753768921
# Epoch 98/200
# Total Training Loss 6.257147192955017
# Avg Training Loss 0.12514294385910035
# Epoch 99/200
# Total Training Loss 6.416358590126038
# Avg Training Loss 0.12832717180252076
# Epoch 100/200
# Total Training Loss 6.112407684326172
# Avg Training Loss 0.12224815368652343
# Epoch 101/200
# Total Training Loss 6.143543004989624
# Avg Training Loss 0.12287086009979248
# Epoch 102/200
# Total Training Loss 6.038388609886169
# Avg Training Loss 0.12076777219772339
# Epoch 103/200
# Total Training Loss 6.372935771942139
# Avg Training Loss 0.12745871543884277
# Epoch 104/200
# Total Training Loss 5.873895168304443
# Avg Training Loss 0.11747790336608886
# Epoch 105/200
# Total Training Loss 5.883523344993591
# Avg Training Loss 0.11767046689987183
# Epoch 106/200
# Total Training Loss 5.572876691818237
# Avg Training Loss 0.11145753383636475
# Epoch 107/200
# Total Training Loss 6.309502005577087
# Avg Training Loss 0.12619004011154175
# Epoch 108/200
# Total Training Loss 6.320833683013916
# Avg Training Loss 0.1264166736602783
# Epoch 109/200
# Total Training Loss 6.427976608276367
# Avg Training Loss 0.12855953216552735
# Epoch 110/200
# Total Training Loss 5.996527910232544
# Avg Training Loss 0.11993055820465087
# Epoch 111/200
# Total Training Loss 5.77864670753479
# Avg Training Loss 0.1155729341506958
# Epoch 112/200
# Total Training Loss 6.4338706731796265
# Avg Training Loss 0.12867741346359252
# Epoch 113/200
# Total Training Loss 6.031014561653137
# Avg Training Loss 0.12062029123306274
# Epoch 114/200
# Total Training Loss 6.252675175666809
# Avg Training Loss 0.1250535035133362
# Epoch 115/200
# Total Training Loss 6.11238968372345
# Avg Training Loss 0.12224779367446899
# Epoch 116/200
# Total Training Loss 6.433804154396057
# Avg Training Loss 0.12867608308792114
# Epoch 117/200
# Total Training Loss 5.884902477264404
# Avg Training Loss 0.11769804954528809
# Epoch 118/200
# Total Training Loss 6.3135082721710205
# Avg Training Loss 0.1262701654434204
# Epoch 119/200
# Total Training Loss 5.996597647666931
# Avg Training Loss 0.11993195295333862
# Epoch 120/200
# Total Training Loss 6.318049669265747
# Avg Training Loss 0.12636099338531495
# Epoch 121/200
# Total Training Loss 5.759805202484131
# Avg Training Loss 0.11519610404968261
# Epoch 122/200
# Total Training Loss 6.107009291648865
# Avg Training Loss 0.1221401858329773
# Epoch 123/200
# Total Training Loss 6.031038045883179
# Avg Training Loss 0.12062076091766358
# Epoch 124/200
# Total Training Loss 5.676405668258667
# Avg Training Loss 0.11352811336517334
# Epoch 125/200
# Total Training Loss 6.316685199737549
# Avg Training Loss 0.12633370399475097
# Epoch 126/200
# Total Training Loss 6.297638177871704
# Avg Training Loss 0.1259527635574341
# Epoch 127/200
# Total Training Loss 6.0172039270401
# Avg Training Loss 0.12034407854080201
# Epoch 128/200
# Total Training Loss 6.2405089139938354
# Avg Training Loss 0.12481017827987671
# Epoch 129/200
# Total Training Loss 5.951481461524963
# Avg Training Loss 0.11902962923049927
# Epoch 130/200
# Total Training Loss 5.976148843765259
# Avg Training Loss 0.11952297687530518
# Epoch 131/200
# Total Training Loss 5.996518969535828
# Avg Training Loss 0.11993037939071655
# Epoch 132/200
# Total Training Loss 5.986199140548706
# Avg Training Loss 0.11972398281097413
# Epoch 133/200
# Total Training Loss 6.2822288274765015
# Avg Training Loss 0.12564457654953004
# Epoch 134/200
# Total Training Loss 6.371458888053894
# Avg Training Loss 0.12742917776107787
# Epoch 135/200
# Total Training Loss 6.427983283996582
# Avg Training Loss 0.12855966567993163
# Epoch 136/200
# Total Training Loss 6.025207996368408
# Avg Training Loss 0.12050415992736817
# Epoch 137/200
# Total Training Loss 6.1123985052108765
# Avg Training Loss 0.12224797010421753
# Epoch 138/200
# Total Training Loss 5.607412755489349
# Avg Training Loss 0.11214825510978699
# Epoch 139/200
# Total Training Loss 6.135982394218445
# Avg Training Loss 0.1227196478843689
# Epoch 140/200
# Total Training Loss 5.999433279037476
# Avg Training Loss 0.11998866558074951
# Epoch 141/200
# Total Training Loss 5.847114682197571
# Avg Training Loss 0.11694229364395142
# Epoch 142/200
# Total Training Loss 6.213085651397705
# Avg Training Loss 0.12426171302795411
# Epoch 143/200
# Total Training Loss 5.66935658454895
# Avg Training Loss 0.113387131690979
# Epoch 144/200
# Total Training Loss 5.6503729820251465
# Avg Training Loss 0.11300745964050293
# Epoch 145/200
# Total Training Loss 5.923173546791077
# Avg Training Loss 0.11846347093582153
# Epoch 146/200
# Total Training Loss 6.017198920249939
# Avg Training Loss 0.12034397840499877
# Epoch 147/200
# Total Training Loss 5.9403475522994995
# Avg Training Loss 0.11880695104598998
# Epoch 148/200
# Total Training Loss 5.978967547416687
# Avg Training Loss 0.11957935094833375
# Epoch 149/200
# Total Training Loss 5.996510982513428
# Avg Training Loss 0.11993021965026855
# Epoch 150/200
# Total Training Loss 6.014431357383728
# Avg Training Loss 0.12028862714767456
# Epoch 151/200
# Total Training Loss 6.010098457336426
# Avg Training Loss 0.12020196914672851
# Epoch 152/200
# Total Training Loss 5.965177893638611
# Avg Training Loss 0.11930355787277222
# Epoch 153/200
# Total Training Loss 6.197828888893127
# Avg Training Loss 0.12395657777786255
# Epoch 154/200
# Total Training Loss 6.002341389656067
# Avg Training Loss 0.12004682779312134
# Epoch 155/200
# Total Training Loss 5.904983043670654
# Avg Training Loss 0.11809966087341309
# Epoch 156/200
# Total Training Loss 5.916183829307556
# Avg Training Loss 0.11832367658615112
# Epoch 157/200
# Total Training Loss 5.825631141662598
# Avg Training Loss 0.11651262283325195
# Epoch 158/200
# Total Training Loss 6.143553733825684
# Avg Training Loss 0.12287107467651368
# Epoch 159/200
# Total Training Loss 6.192570686340332
# Avg Training Loss 0.12385141372680664
# Epoch 160/200
# Total Training Loss 6.3606345653533936
# Avg Training Loss 0.12721269130706786
# Epoch 161/200
# Total Training Loss 6.248202443122864
# Avg Training Loss 0.12496404886245728
# Epoch 162/200
# Total Training Loss 6.031001329421997
# Avg Training Loss 0.12062002658843994
# Epoch 163/200
# Total Training Loss 6.389048457145691
# Avg Training Loss 0.12778096914291381
# Epoch 164/200
# Total Training Loss 6.153353929519653
# Avg Training Loss 0.12306707859039306
# Epoch 165/200
# Total Training Loss 6.325628280639648
# Avg Training Loss 0.12651256561279298
# Epoch 166/200
# Total Training Loss 6.263087153434753
# Avg Training Loss 0.12526174306869506
# Epoch 167/200
# Total Training Loss 5.9965115785598755
# Avg Training Loss 0.1199302315711975
# Epoch 168/200
# Total Training Loss 6.352286696434021
# Avg Training Loss 0.12704573392868043
# Epoch 169/200
# Total Training Loss 6.010099768638611
# Avg Training Loss 0.12020199537277222
# Epoch 170/200
# Total Training Loss 6.01010000705719
# Avg Training Loss 0.1202020001411438
# Epoch 171/200
# Total Training Loss 5.673240303993225
# Avg Training Loss 0.1134648060798645
# Epoch 172/200
# Total Training Loss 6.150385737419128
# Avg Training Loss 0.12300771474838257
# Epoch 173/200
# Total Training Loss 5.996511816978455
# Avg Training Loss 0.11993023633956909
# Epoch 174/200
# Total Training Loss 6.285664439201355
# Avg Training Loss 0.1257132887840271
# Epoch 175/200
# Total Training Loss 5.951592326164246
# Avg Training Loss 0.11903184652328491
# Epoch 176/200
# Total Training Loss 6.030789613723755
# Avg Training Loss 0.1206157922744751
# Epoch 177/200
# Total Training Loss 5.559065937995911
# Avg Training Loss 0.11118131875991821
# Epoch 178/200
# Total Training Loss 5.996510744094849
# Avg Training Loss 0.11993021488189698
# Epoch 179/200
# Total Training Loss 6.10024619102478
# Avg Training Loss 0.1220049238204956
# Epoch 180/200
# Total Training Loss 6.1435524225234985
# Avg Training Loss 0.12287104845046998
# Epoch 181/200
# Total Training Loss 6.281285881996155
# Avg Training Loss 0.12562571763992308
# Epoch 182/200
# Total Training Loss 6.195396184921265
# Avg Training Loss 0.12390792369842529
# Epoch 183/200
# Total Training Loss 6.360625386238098
# Avg Training Loss 0.12721250772476198
# Epoch 184/200
# Total Training Loss 6.433960318565369
# Avg Training Loss 0.12867920637130736
# Epoch 185/200
# Total Training Loss 6.31375789642334
# Avg Training Loss 0.1262751579284668
# Epoch 186/200
# Total Training Loss 6.115659594535828
# Avg Training Loss 0.12231319189071656
# Epoch 187/200
# Total Training Loss 6.195382237434387
# Avg Training Loss 0.12390764474868775
# Epoch 188/200
# Total Training Loss 6.191210150718689
# Avg Training Loss 0.12382420301437377
# Epoch 189/200
# Total Training Loss 6.005934357643127
# Avg Training Loss 0.12011868715286254
# Epoch 190/200
# Total Training Loss 5.996517777442932
# Avg Training Loss 0.11993035554885864
# Epoch 191/200
# Total Training Loss 5.860266089439392
# Avg Training Loss 0.11720532178878784
# Epoch 192/200
# Total Training Loss 6.43391489982605
# Avg Training Loss 0.128678297996521
# Epoch 193/200
# Total Training Loss 6.031009793281555
# Avg Training Loss 0.12062019586563111
# Epoch 194/200
# Total Training Loss 6.0479607582092285
# Avg Training Loss 0.12095921516418456
# Epoch 195/200
# Total Training Loss 6.150377035140991
# Avg Training Loss 0.12300754070281983
# Epoch 196/200
# Total Training Loss 6.026946306228638
# Avg Training Loss 0.12053892612457276
# Epoch 197/200
# Total Training Loss 5.825374364852905
# Avg Training Loss 0.11650748729705811
# Epoch 198/200
# Total Training Loss 6.291536092758179
# Avg Training Loss 0.12583072185516359
# Epoch 199/200
# Total Training Loss 6.237975120544434
# Avg Training Loss 0.12475950241088868
# Epoch 200/200
# Total Training Loss 6.3714224100112915
# Avg Training Loss 0.12742844820022584

# %%
plt.ylabel('Total Loss per epoch')
plt.xlabel('Epochs')
plt.plot(train_loss_hist, label='Cross Entropy Loss')
plt.legend()
plt.show()

# %%
print('Post Training: ')
for i in (idx):
    img, label = data.__getitem__(i)
    visualize_predictions(model, img)
# Out:
# Post Training:
